# %% [markdown]
# # Práctica Big Data Architecture
#
# En este colab voy a desarrollar la parte práctica del ejercicio. Dado que Google cloud nos permite gestionar los recursos que necesitemos con su API he optado por automatizar todo el proceso. Así que en este colab se van a generar los ficheros a partir del [API de Stack Exchange](https://api.stackexchange.com/), se va a crear el cluster de Hadoop, se van a lanzar los jobs de Hadoop y Hive y se va a visualizar el resultado de estos jobs
#
# Para realizar las llamadas al API de Stack Exchange usamos la librería de [Python Requests](http://docs.python-requests.org/en/master/)
#
# Para realizar las operaciones sobre Google Cloud usamos la [librería que proporciona Google](https://developers.google.com/api-client-library/python/)
#
# Ahora vamos a realizar los imports necesarios, inicializamos las variantes que identifican al cluster, ficheros, storage, etc.
# Para poder realizar las tareas en Google Cloud se necestira un fichero de credenciales como se explica [en este enlace](https://cloud.google.com/docs/authentication/getting-started). Durante la ejecución se solicitará que se suba el fichero de credenciales. Es relativamente seguro porque se  sube a tu Google Drive.

# %%
import json
import requests

from datetime import datetime, timedelta
import time
import os

from googleapiclient.discovery import build
from oauth2client.client import GoogleCredentials

# damos permiso a google colab para poder usar gsutil y subir los ficheros generados a nuestro Google Storage
from google.colab import auth
auth.authenticate_user()

# Para ello hay que proporcionar un fichero de credenciales de Google cloud. 
# El siguiente pide el fichero de credenciales para subirlo a Google Drive
from google.colab import files
uploaded = files.upload()

# ID del proyecto de Google Cloud
project_id = "positive-record-228820"

# Nombre con en el que se va a crear el cluster de Hadoop
cluster_name = "cluster-bdarchitecture-stackoverflow"

# Zona donde se va a crear el cluster
zone = "europe-west4-a"

# Region donde se va a crear el cluster
region = "europe-west4"

# Nombre del bucket de Google Storage donde se van a almacenar los ficheros
bucket_name = "dataproc-d3c1f40b-c187-47f1-a030-87fd5670b613-europe-north1"
os.environ['BUCKET_NAME'] = bucket_name

# IMPORTANTE!!!!  Este nombre de fichero debe ser el del fichero subido en el paso anterior
credentials_file = 'BD-Architecture-157d0541f3f7.json'
# Out:
#      <input type="file" id="files-123dd5a1-72a5-4ab1-899a-f1f0394288ce" name="files[]" multiple disabled />
#      <output id="result-123dd5a1-72a5-4ab1-899a-f1f0394288ce">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving BD-Architecture-157d0541f3f7.json to BD-Architecture-157d0541f3f7.json

# %% [markdown]
# ## Spring 2
#
# Vamos a generar dos ficheros con el API que proporciona Stack Exchange.
#
# En el primer fichero vamos a obtener todos los usuarios que hayan respondido a una pregunta en Stack Overflow en el último día. Opcionalmente se puede ampliar este periodo de tiempo, aunque conviene no subir mucho este número ya que el API nos limita a 300 peticiones al API durante 6 horas.
#
# El segundo fichero, a partir de los IDs obtenidos en el primer fichero, vamos a obtener los nombres, reputación y pais de cada usuario. Ambos ficheros se almacenan en el bucket configurado

# %%
# obtenemos la fecha de hace 1 dia
d = datetime.today() - timedelta(days=1)

fromdate = int(d.timestamp())

url_base = "https://api.stackexchange.com/2.2/answers?&order=asc&sort=activity&site=stackoverflow&pagesize=100&fromdate=" + str(fromdate)
has_more = True
pagina = 1

with open('user_ids_answers', 'w') as f_user_ids_answers:    
    while(has_more) :
        url_request = url_base + "&page=" + str(pagina)
        response = requests.get(url_request)

        result = response.json()
        
        if (result.get('error_id')):
            print("Error: " + result.get('error_message'))
            break;

        
        for answer in result['items']:
            owner = answer['owner']
            if (owner.get('user_id')): # algunas peticiones no traen el user_id
              f_user_ids_answers.write(str(answer['owner']['user_id']) + "\n")

        print(end=".")

        has_more = result['has_more']
        pagina = pagina + 1
        time.sleep(1)

# Subimos el fichero al storage de Google Cloud
# !gsutil cp user_ids_answers gs://$BUCKET_NAME
# Out:
# .............................

# %%
# !rm user_ids_names
# ahora que user ID de los usurios que han comentado, obtemos el nombre de usuario de cada uno para luego cruzar los datos en HIVE
# con el nombre de usuario y el is generamos un fichero csv
with open('user_ids_answers', 'r') as f_user_ids_answers:
    # El API de stackexchange nos permite 
    # https://api.stackexchange.com/docs/users-by-ids

    i = 0
    users_url = ""
    for user_id in f_user_ids_answers:
        user_id = f_user_ids_answers.readline().rstrip()
        
        if (i >= 100):
            # quitamos el ultimo ; y hacemos la peticion para obtener los datos de los usuarios
            users_url = users_url[:-1]
            url = "https://api.stackexchange.com/2.2/users/" + users_url + "?pagesize=100&order=desc&sort=reputation&site=stackoverflow"
            #print(url)
            print(end=".")
            response = requests.get(url)
            result = response.json()

            with open('user_ids_names', 'a') as f_user_ids_names:
                if (result.get('error_id')):
                    print("Error: " + result.get('error_message'))
                else:    
                    for user in result['items']:
                        user_id = user['user_id']
                        name = user.get('display_name')
                        reputation = user.get('reputation')
                        location = user.get('location')
                        f_user_ids_names.write(str(user_id) + "," + name + "," + str(reputation) + "," + str(location) + "\n")

            i = 0
            users_url = ""
        
        users_url = users_url + str(user_id) + ";"
        i = i + 1



#!cat user_ids_answers
#!pwd
#!ls
#!cat user_ids_answers
#from google.colab import files
#files.download('user_ids_answers')
#files.download('user_ids_names')

# Subimos el fichero al storage de Google Cloud
# !gsutil cp user_ids_names gs://$BUCKET_NAME/
# Out:
# rm: cannot remove 'user_ids_names': No such file or directory
# ..............................................Copying file://user_ids_names [Content-Type=application/octet-stream]...
# -
# Operation completed over 1 objects/162.1 KiB.

# %% [markdown]
# ## Spring 3
#
# En este paso creamos el cluster en Google cloud. El cluster va a constar de un nodo master y dos slaves. Dado que no necesitamos gran potencia de proceso he configurado el cluster con las instancias más pequeñas y un espacio en disco de 30GB cada una.

# %%
# Ahora vamos a crear el cluster en Google Cloud mediante el API de Python que proporciona Google.

def get_client():
  """Builds a client to the dataproc API."""
  dataproc = build('dataproc', 'v1', credentials=credentials)
  return dataproc

def create_cluster(dataproc, project, zone, region, cluster_name, bucket_name):
  print('Creating cluster...')
  zone_uri = \
    'https://www.googleapis.com/compute/v1/projects/{}/zones/{}'.format(
      project, zone)
  cluster_data = {
    'projectId': project,
    'clusterName': cluster_name,
    'config': {
      "configBucket": bucket_name,
      'gceClusterConfig': {
        'zoneUri': zone_uri
      },
      'masterConfig': {
        'numInstances': 1,
        'machineTypeUri': 'n1-standard-1',
        'diskConfig': {
          "bootDiskType": "pd-standard",
          "bootDiskSizeGb": 30,
          "numLocalSsds": 0
        }
      },
      'workerConfig': {
        'numInstances': 2,
        'machineTypeUri': 'n1-standard-1',
        "diskConfig": {
          "bootDiskType": "pd-standard",
          "bootDiskSizeGb": 30,
          "numLocalSsds": 0
        }
      },
      "softwareConfig": {
        "imageVersion": "1.3-deb9"
      },
      "secondaryWorkerConfig": {
        "numInstances": 0,
        "isPreemptible": True
      }
    }
  }
  result = dataproc.projects().regions().clusters().create(
    projectId=project,
    region=region,
    body=cluster_data).execute()
  return result


def list_clusters(dataproc, project, region):
  result = dataproc.projects().regions().clusters().list(
    projectId=project,
    region=region).execute()
  return result

credentials = GoogleCredentials.from_stream(credentials_file)

dataproc = get_client()
create_cluster(dataproc, project_id, zone, region, cluster_name, bucket_name)
# Out:
# Creating cluster...
# {'metadata': {'@type': 'type.googleapis.com/google.cloud.dataproc.v1.ClusterOperationMetadata',
#   'clusterName': 'cluster-bdarchitecture-stackoverflow',
#   'clusterUuid': '364ad0fc-807e-4906-be34-c4accb397daa',
#   'description': 'Create cluster with 2 workers',
#   'operationType': 'CREATE',
#   'status': {'innerState': 'PENDING',
#    'state': 'PENDING',
#    'stateStartTime': '2019-01-24T18:09:42.258Z'},
#   'warnings': ['For PD-Standard, we strongly recommend provisioning 1TB or larger to ensure consistently high I/O performance. See https://cloud.google.com/compute/docs/disks/performance for information on disk I/O performance.']},
#  'name': 'projects/positive-record-228820/regions/europe-west4/operations/dbbb670f-7c91-494b-ace8-100268a72a7d'}

# %% [markdown]
# ## Spring 4
#
# Lanzamos un trabajo al cluster hadoop que ejecuta un WordCount sobre el fichero con los IDs de los  usuarios que han realizado alguna respuesta en el último día. Así cuantas veces ha respondido cada usuario.

# %%
# En este paso esperamos a que se cree el culster y despues lanzamos un job para que se haga el wordcount del fichero de IDS
def submit_haddop_job(dataproc, project, region,
                       cluster_name, bucket_name, filename):
  job_details = {
    'projectId': project,
    'job': {
      'placement': {
        'clusterName': cluster_name
      },
      'hadoopJob': {
        "args": ["wordcount", 'gs://{}/{}'.format(bucket_name, filename), "output"],
        "mainJarFileUri": "file:////usr/lib/hadoop-mapreduce/hadoop-mapreduce-examples.jar"
      }
    }
  }
  result = dataproc.projects().regions().jobs().submit(
    projectId=project,
    region=region,
    body=job_details).execute()
  job_id = result['reference']['jobId']
  print('Submitted job ID {}'.format(job_id))
  return job_id

def wait_for_job(dataproc, project, region, job_id):
  print('Waiting for job to finish...')
  while True:
    result = dataproc.projects().regions().jobs().get(
    projectId=project,
    region=region,
    jobId=job_id).execute()
    # Handle exceptions
    if result['status']['state'] == 'ERROR':
      raise Exception(result['status']['details'])
    elif result['status']['state'] == 'DONE':
      print('Job finished.')
      return result

while True:
  print("waiting cluster creation") 
  clusters = list_clusters(dataproc, project_id, region)

  cluster_running = False
  for cluster in clusters.get('clusters'):
    #print(cluster['clusterName'])
    print("CLUSTER STATE: " + cluster['status']['state'])
    if cluster['clusterName'] == cluster_name and cluster['status']['state'] == 'RUNNING':
      cluster_running = True

  if cluster_running:
    break
  time.sleep(10)
  
job_id = submit_haddop_job(dataproc, project_id, region, cluster_name, bucket_name, "user_ids_answers")
## esperamos a que termine el job  
wait_for_job(dataproc, project_id, region, job_id)
# Out:
# CREATING
# CREATING
# CREATING
# CREATING
# CREATING
# CREATING
# CREATING
# CREATING
# CREATING
# CREATING
# CREATING
# CREATING
# CREATING
# CREATING
# CREATING
# RUNNING
# Submitted job ID d6e0e4b2-016c-438b-b949-b42e46b334ce
# Waiting for job to finish...
# Job finished.
# {'driverControlFilesUri': 'gs://dataproc-d3c1f40b-c187-47f1-a030-87fd5670b613-europe-north1/google-cloud-dataproc-metainfo/364ad0fc-807e-4906-be34-c4accb397daa/jobs/d6e0e4b2-016c-438b-b949-b42e46b334ce/',
#  'driverOutputResourceUri': 'gs://dataproc-d3c1f40b-c187-47f1-a030-87fd5670b613-europe-north1/google-cloud-dataproc-metainfo/364ad0fc-807e-4906-be34-c4accb397daa/jobs/d6e0e4b2-016c-438b-b949-b42e46b334ce/driveroutput',
#  'hadoopJob': {'args': ['wordcount',
#    'gs://dataproc-d3c1f40b-c187-47f1-a030-87fd5670b613-europe-north1/user_ids_answers',
#    'output'],
#   'mainJarFileUri': 'file:////usr/lib/hadoop-mapreduce/hadoop-mapreduce-examples.jar'},
#  'jobUuid': 'd6e0e4b2-016c-438b-b949-b42e46b334ce',
#  'placement': {'clusterName': 'cluster-bdarchitecture-stackoverflow',
#   'clusterUuid': '364ad0fc-807e-4906-be34-c4accb397daa'},
#  'reference': {'jobId': 'd6e0e4b2-016c-438b-b949-b42e46b334ce',
#   'projectId': 'positive-record-228820'},
#  'status': {'state': 'DONE', 'stateStartTime': '2019-01-24T18:13:06.165Z'},
#  'statusHistory': [{'state': 'PENDING',
#    'stateStartTime': '2019-01-24T18:12:20.539Z'},
#   {'state': 'SETUP_DONE', 'stateStartTime': '2019-01-24T18:12:20.627Z'},
#   {'details': 'Agent reported job success',
#    'state': 'RUNNING',
#    'stateStartTime': '2019-01-24T18:12:20.960Z'}],
#  'yarnApplications': [{'name': 'word count',
#    'progress': 1,
#    'state': 'FINISHED',
#    'trackingUrl': 'http://cluster-bdarchitecture-stackoverflow-m:8088/proxy/application_1548353444959_0001/'}]}

# %% [markdown]
# ## Spring 5
#
# Lanzamos un trabajo en hive que realiza las siguientes acciones:
#
# * Creamos la tabla user_answers con el contenido del fichero generado en hdfs por el trabajo de WordCount
# * Creamos la tabla users con el contenido del fichero que tiene el id del usuario, nombre, reputación y localización.
# * Creamos la tabla externa users_most_actives que generará un archivo en el bucket de Storage con los usuarios más activos.
# * Cargamos la tabla users_most_actives con una consulta en la que obtenemos los usuarios, con su id, su nombre y el número de respuestas que han realizado.
# * Creamos la tabla externa locations_most_actives que generará un archivo en el bucket de Storage con las localizaciones con los usuarios más activos.
# * Cargamos la tabla locations_most_actives con una consulta en la que obtenemos las localizaciones y el número de respuestas que han realizado los usuarios de cada localización.

# %%
# !gsutil cp user_ids_names gs://$BUCKET_NAME/
## realizamos la consultas de hive
def submit_hive_job(dataproc, project, region,
                       cluster_name, querys):
  job_details = {
    'projectId': project,
    'job': {
      'placement': {
        'clusterName': cluster_name
      },
      'hiveJob': {
        "queryList": {
            "queries": querys
        }
      }
    }
  }
  #["CREATE TABLE IF NOT EXISTS users\n (user_id INT, name STRING, reputation INT, location STRING)\n row format delimited fields terminated by ',';\n\nLOAD DATA INPATH 'gs://dataproc-d3c1f40b-c187-47f1-a030-87fd5670b613-europe-north1/user_ids_names' INTO TABLE users;\n\nCREATE TABLE IF NOT EXISTS user_answers\n (user_id INT, n_answers INT) row format delimited fields terminated by '\\t';\n\nLOAD DATA INPATH 'hdfs:///user/root/output/*' INTO TABLE user_answers;\n\nCREATE EXTERNAL TABLE IF NOT EXISTS users_most_actives(\n user_id INT, name STRING, n_answers INT)\n ROW FORMAT DELIMITED\n FIELDS TERMINATED BY ','\n STORED AS TEXTFILE\n LOCATION 'gs://dataproc-d3c1f40b-c187-47f1-a030-87fd5670b613-europe-north1/users_most_actives';\n\nINSERT OVERWRITE TABLE users_most_actives SELECT DISTINCT users.user_id, users.name, user_answers.n_answers \nFROM users JOIN user_answers ON users.user_id = user_answers.user_id \nORDER BY n_answers DESC;"]
  result = dataproc.projects().regions().jobs().submit(
    projectId=project,
    region=region,
    body=job_details).execute()
  job_id = result['reference']['jobId']
  print('Submitted job ID {}'.format(job_id))
  return job_id


# preparamos las querys
sql_hive = []
sql_hive.append("CREATE TABLE IF NOT EXISTS users \
(user_id INT, name STRING, reputation INT, location STRING) \
row format delimited fields terminated by ',';")

sql_hive.append("LOAD DATA INPATH 'gs://{}/user_ids_names' INTO TABLE users;".format(bucket_name))

sql_hive.append("CREATE TABLE IF NOT EXISTS user_answers\
(user_id INT, n_answers INT) row format delimited fields terminated by '\t';")

sql_hive.append("LOAD DATA INPATH 'hdfs:///user/root/output/*' INTO TABLE user_answers;")

sql_hive.append("CREATE EXTERNAL TABLE IF NOT EXISTS users_most_actives(\
user_id INT, name STRING, n_answers INT) \
ROW FORMAT DELIMITED \
FIELDS TERMINATED BY ',' \
STORED AS TEXTFILE \
LOCATION 'gs://{}/users_most_actives';".format(bucket_name))

sql_hive.append("INSERT OVERWRITE TABLE users_most_actives SELECT DISTINCT users.user_id, users.name, user_answers.n_answers  \
FROM users JOIN user_answers ON users.user_id = user_answers.user_id  \
ORDER BY n_answers DESC;")

sql_hive.append("CREATE EXTERNAL TABLE IF NOT EXISTS localtions_most_actives( \
location STRING, n_answers INT) \
ROW FORMAT DELIMITED \
FIELDS TERMINATED BY ',' \
STORED AS TEXTFILE \
LOCATION 'gs://{}/locations_most_actives';".format(bucket_name))

sql_hive.append("INSERT OVERWRITE TABLE localtions_most_actives SELECT location, SUM(user_answers.n_answers) TOTAL \
FROM users JOIN user_answers ON users.user_id = user_answers.user_id  \
GROUP BY location \
ORDER BY TOTAL DESC;")

job_id = submit_hive_job(dataproc, project_id, region, cluster_name, sql_hive)
wait_for_job(dataproc, project_id, region, job_id)
# Out:
# Copying file://user_ids_names [Content-Type=application/octet-stream]...
# / [1 files][162.1 KiB/162.1 KiB]
# Operation completed over 1 objects/162.1 KiB.
# Submitted job ID 0904075e-78fa-4208-ab38-c8205428ed3b
# Waiting for job to finish...
# Job finished.
# {'driverControlFilesUri': 'gs://dataproc-d3c1f40b-c187-47f1-a030-87fd5670b613-europe-north1/google-cloud-dataproc-metainfo/364ad0fc-807e-4906-be34-c4accb397daa/jobs/0904075e-78fa-4208-ab38-c8205428ed3b/',
#  'driverOutputResourceUri': 'gs://dataproc-d3c1f40b-c187-47f1-a030-87fd5670b613-europe-north1/google-cloud-dataproc-metainfo/364ad0fc-807e-4906-be34-c4accb397daa/jobs/0904075e-78fa-4208-ab38-c8205428ed3b/driveroutput',
#  'hiveJob': {'queryList': {'queries': ["CREATE TABLE IF NOT EXISTS users (user_id INT, name STRING, reputation INT, location STRING) row format delimited fields terminated by ',';",
#     "LOAD DATA INPATH 'gs://dataproc-d3c1f40b-c187-47f1-a030-87fd5670b613-europe-north1/user_ids_names' INTO TABLE users;",
#     "CREATE TABLE IF NOT EXISTS user_answers(user_id INT, n_answers INT) row format delimited fields terminated by '\t';",
#     "LOAD DATA INPATH 'hdfs:///user/root/output/*' INTO TABLE user_answers;",
#     "CREATE EXTERNAL TABLE IF NOT EXISTS users_most_actives(user_id INT, name STRING, n_answers INT) ROW FORMAT DELIMITED FIELDS TERMINATED BY ',' STORED AS TEXTFILE LOCATION 'gs://dataproc-d3c1f40b-c187-47f1-a030-87fd5670b613-europe-north1/users_most_actives';",
#     'INSERT OVERWRITE TABLE users_most_actives SELECT DISTINCT users.user_id, users.name, user_answers.n_answers  FROM users JOIN user_answers ON users.user_id = user_answers.user_id  ORDER BY n_answers DESC;',
#     "CREATE EXTERNAL TABLE IF NOT EXISTS localtions_most_actives( location STRING, n_answers INT) ROW FORMAT DELIMITED FIELDS TERMINATED BY ',' STORED AS TEXTFILE LOCATION 'gs://dataproc-d3c1f40b-c187-47f1-a030-87fd5670b613-europe-north1/locations_most_actives';",
#     'INSERT OVERWRITE TABLE localtions_most_actives SELECT location, SUM(user_answers.n_answers) TOTAL FROM users JOIN user_answers ON users.user_id = user_answers.user_id  GROUP BY location ORDER BY TOTAL DESC;']}},
#  'jobUuid': '0904075e-78fa-4208-ab38-c8205428ed3b',
#  'placement': {'clusterName': 'cluster-bdarchitecture-stackoverflow',
#   'clusterUuid': '364ad0fc-807e-4906-be34-c4accb397daa'},
#  'reference': {'jobId': '0904075e-78fa-4208-ab38-c8205428ed3b',
#   'projectId': 'positive-record-228820'},
#  'status': {'state': 'DONE', 'stateStartTime': '2019-01-24T18:16:24.840Z'},
#  'statusHistory': [{'state': 'PENDING',
#    'stateStartTime': '2019-01-24T18:14:32.497Z'},
#   {'state': 'SETUP_DONE', 'stateStartTime': '2019-01-24T18:14:32.552Z'},
#   {'details': 'Agent reported job success',
#    'state': 'RUNNING',
#    'stateStartTime': '2019-01-24T18:14:33Z'}]}

# %% [markdown]
# ## Consulta de resultados.
#
# Primero eliminamos el cluster
#
# Luego nos traemos los archivos generado en hive y consultamos los resultados.
#
# Primero consultamos los usuarios mas activos.

# %%
# !gsutil cp -r gs://$BUCKET_NAME/users_most_actives .
# !cat users_most_actives/*
# Out:
# Copying gs://dataproc-d3c1f40b-c187-47f1-a030-87fd5670b613-europe-north1/users_most_actives/000000_0...
# / [1 files][ 73.2 KiB/ 73.2 KiB]
# Operation completed over 1 objects/73.2 KiB.
# 1144035,Gordon Linoff,28
# 9209546,jpp,26
# 1118978,Simonare,23
# 1447675,Nina Scholz,19
# 6766919,Ashay Mandwarya,15
# 3528136,Eric Svitok,15
# 1691980,Bruno Caceiro,14
# 9332897,Nikola Gavric,14
# 10611983,Tomothy32,13
# 2901002,jezrael,13
# 2308683,cricket_007,13
# 10955263,04FS,13
# 654031,Chris Pratt,12
# 10953560,Chien Nguyen,12
# 8620333,Temani Afif,12
# 7964527,W-B,12
# 10953776,anand_v.singh,11
# 209103,Frank van Puffelen,11
# 2622292,SiddAjmera,11
# 3044560,Umair Farooq,11
# 3832970,Wiktor Stribiżew,11
# 2549110,Gauravsa,10
# 5529445,Yogesh Sharma,10
# 10938799,IAmNerd2000,10
# 4279120,olinox14,10
# 1419590,Saraband,10
# 1491895,Barmar,10
# 5648954,Nick Parsons,9
# 6914864,fa06,9
# 9518890,Matus Dubrava,9
# 104349,Daniel Roseman,9
# 2890724,Raydel Miranda,9
# 4909087,coldspeed,9
# 10221765,Jack Bashford,8
# 10260537,Joe,8
# 10953743,Suraj M,8
# 19068,Quentin,8
# 41316,bruno desthuilliers,8
# 922613,George P,8
# 1863229,Tim Biegeleisen,8
# 3732271,akrun,8
# 5362469,Naya,8
# 5866580,RavinderSingh13,8
# 9325419,jo_va,8
# 9473764,Nick,8
# 5044042,vadian,7
# 5372008,Teocci,7
# 5928070,TanvirArjel,7
# 6064494,zED,7
# 8129670,Jelle,7
# 8407242,Ritviz Sharma,7
# 8764421,Atley Varghese,7
# 10498828,forpas,7
# 10877860,Muhammad Waheed,7
# 1048572,Bergi,7
# 1678467,tnknepp,7
# 3219613,Pᴇʜ,7
# 10957435,Chipster,6
# 10959845,Sameer Arora,6
# 10961994,Dheeraj Goud Puppali,6
# 217408,G&#252;nter Z&#246;chbauer,6
# 519413,Rory McCrossan,6
# 544825,max,6
# 548225,anubhava,6
# 997358,peak,6
# 1039555,Kartik,6
# 1213708,Nigel Ren,6
# 1226963,rmaddy,6
# 1240763,Gary Russell,6
# 1377002,Andy,6
# 1405634,Prisoner,6
# 1647604,DeborahK,6
# 1815797,gniourf_gniourf,6
# 2079303,eerorika,6
# 2181397,brk,6
# 2380830,Bathsheba,6
# 2684539,Jarod42,6
# 2711488,Holger,6
# 3429015,Danon,6
# 4974180,Slava Murygin,6
# 5021687,Alexander Volok,6
# 5424988,The fourth bird,6
# 6058626,fuNcti0n,6
# 6067741,4c74356b41,6
# 6808583,Zaynul Abadin Tuhin,6
# 8016720,John Hanley,6
# 8235774,Emirhan &#214;ZKAN,6
# 9308321,Mohit Gupta,6
# 9449434,Sukhjinder Singh,6
# 9661424,sticky bit,6
# 9942418,Islam Elshobokshy,6
# 10490334,Hensler Software,6
# 10911323,sabbir chowdury,6
# 10911905,Nuzhny,6
# 10923441,samjamy,6
# 10950630,Abulafia,6
# 10954839,User Usersur,6
# 10956648,TheMouseMaster,6
# 5173426,user5173426,5
# 5260024,Jonas Wilms,5
# 5403468,Tiw,5
# 5483526,Matt Timmermans,5
# 5508175,Andrew,5
# 6005805,spaniard,5
# 6089515,Lunin Roman,5
# 6398044,Daniel,5
# 6464308,Laurenz Albe,5
# 6622587,eyllanesc,5
# 6867048,stack0114106,5
# 7061661,P&#233;ter Veres,5
# 7299782,Anu Viswan,5
# 7751011,Pascal Tovohery,5
# 7894027,Mozammil,5
# 8382203,Anders Revsgaard,5
# 8558186,Eliseo,5
# 9023746,sjdm,5
# 9072753,Kamil Cuk,5
# 9110909,Omer Tekbiyik,5
# 9297144,Xavier Guihot,5
# 9385780,Baruch G.,5
# 9593596,lubgr,5
# 9673730,Mark.F,5
# 9838946,Timothy T.,5
# 9840637,anky_91,5
# 9958942,benvc,5
# 10205629,ValdaXD,5
# 10225535,Samuel Chavez,5
# 10323798,NelsonGon,5
# 10522579,ray,5
# 10532500,Suraj Kumar,5
# 10550234,Mayank Wadhwa,5
# 10868192,antonku,5
# 10880993,Beniamin H,5
# 10924296,Reedinationer,5
# 10928836,B. Pl&#252;ster,5
# 10933103,Nika Narushvili,5
# 10957075,Dhamik jagodana,5
# 76714,slugolicious,5
# 224132,Peter Cordes,5
# 296069,Ski,5
# 297322,PSK,5
# 435089,Kannappan Sirchabesan,5
# 580346,mrzasa,5
# 812970,Sunil,5
# 1211879,nikneem,5
# 1435869,karakfa,5
# 1602555,Karol Dowbecki,5
# 1612975,TheGeneral,5
# 1773434,Govind Parmar,5
# 2266772,Matthieu Brucher,5
# 2410359,chux,5
# 2668119,DGS,5
# 2775371,inlineMacro,5
# 2793683,dmoore1181,5
# 2836621,Mark Setchell,5
# 2897748,Dmitri T,5
# 2988282,Hungryweb,5
# 3016153,michael.hor257k,5
# 3096012,BobinsonKB,5
# 3307073,ygorbunkov,5
# 3422102,David C. Rankin,5
# 3484879,Larnu,5
# 3634538,jom,5
# 3684265,imvain2,5
# 3701393,holydragon,5
# 3706016,jarlh,5
# 3813116,Sean Lange,5
# 3880585,gaetanoM,5
# 3888766,Amardeep Bhowmick,5
# 4135670,Rafael,5
# 4281779,Zakaria Acharki,5
# 4750892,Asim Khan,5
# 5015238,jdweng,5
# 5159168,Andreas,5
# 101719,Sprotty,4
# 139985,Stephen C,4
# 174777,John Rotenstein,4
# 221700,peterSO,4
# 263693,Stephen Cleary,4
# 314166,sawa,4
# 355230,martineau,4
# 440558,Some programmer dude,4
# 476951,yunzen,4
# 532312,Rakesh,4
# 592355,xerx593,4
# 666221,diegoveloper,4
# 765226,Alexis Olson,4
# 817643,StoryTeller,4
# 938947,widjajayd,4
# 992484,MadProgrammer,4
# 1256452,torek,4
# 1313852,WILLIAM WOODMAN,4
# 1320535,Julius Vainora,4
# 1375553,Vadim Gremyachev,4
# 1442432,Leroy Stav,4
# 1453833,Max,4
# 1474444,jeff,4
# 1527103,Gokhan Oner,4
# 1613406,opewix,4
# 1731626,Sergey,4
# 1788806,Willi Mentzel,4
# 2035262,Aleksei Matiushkin,4
# 2039693,Ramesh Subramanian,4
# 2060966,marsze,4
# 2170191,stever,4
# 2200976,Enrique Chavez,4
# 2227085,Santosh,4
# 2270475,Moody_Mudskipper,4
# 2341603,Obsidian Age,4
# 2389923,beigirad,4
# 2410199,Mocas,4
# 2415802,mwilson,4
# 2548721,Jerome Montino,4
# 2557128,NetMage,4
# 2625560,vsemozhetbyt,4
# 2790312,Raunak Jhawar,4
# 2795592,Konstantin Suvorov,4
# 2813224,zer00ne,4
# 2943345,Дмитро Булах,4
# 2967845,Santosh,4
# 3041229,ValerioMC,4
# 3061852,kfinity,4
# 3094533,Zohar Peled,4
# 3271507,brunorey,4
# 3470178,Juan Carlos Oropeza,4
# 3589092,kemicofa,4
# 3679900,y2k-shubham,4
# 3960815,basic,4
# 4001592,Daniel Mesejo,4
# 4342498,NathanOliver,4
# 4412155,Bheem  Singh,4
# 4458510,Alex,4
# 4851590,Scott Craner,4
# 4859910,Anjaneyulu Batta,4
# 4969398,Ahd Bk,4
# 5133585,Sweeper,4
# 5172395,ethercreation,4
# 5221944,Mikhail Berlyant,4
# 5245033,SergeyA,4
# 5746996,Tobin,4
# 5775048,gatsby,4
# 5849770,Şivā SankĂr,4
# 6022656,max66,4
# 6049940,sskini,4
# 6219171,Nikhil Vaghela,4
# 6232309,Silvio Biasiol,4
# 6241235,QHarr,4
# 6311776,Usama Kiyani,4
# 6312126,Lauren,4
# 6690200,竹杖芒鞋轻胜马,4
# 6747171,Stephan,4
# 6774472,Error 1004,4
# 6890912,blhsing,4
# 7111561,derHugo,4
# 7296893,Erik von Asmuth,4
# 7399631,mumpitz,4
# 7462031,G.hakim,4
# 8166445,dun32,4
# 8187195,Matthias Simon,4
# 8205642,HMVBA,4
# 8223070,Cat,4
# 8237266,vikas biradar,4
# 8506548,nate,4
# 8593338,abcdaire,4
# 8612835,Sachin Shah,4
# 8656248,mscdeveloper,4
# 8726235,Eduardo Soares,4
# 8918475,Cata Hotea,4
# 8960078,HoboProber,4
# 9114247,Daan Beat,4
# 9223839,Joakim Danielson,4
# 9816472,Isaac,4
# 9820210,Sudabe-Neirizi,4
# 9833314,Nancy Xiong,4
# 10089169,Swapnil G Thaware,4
# 10381160,CodeBoyCode,4
# 10418264,Mark Barinstein,4
# 10587554,Lidi Zheng,4
# 10643988,Bill M.,4
# 10676716,GMB,4
# 10814922,Foram Thakral,4
# 10848591,Spinkoo,4
# 10910955,Prince Babbar,4
# 10913596,Daniel,4
# 10917587,Tristan,4
# 10943108,ashish,4
# 10948428,Ali CSE,4
# 10958618,AntoineR,4
# 10959719,PikaChU,4
# 10960120,Saltama,4
# 16940,Simon_Weaver,4
# 23512,Tanktalus,4
# 65863,Remy Lebeau,4
# 100297,Martijn Pieters,4
# 88056,Powertieke,3
# 125734,Titian Cernicova-Dragomir,3
# 131930,Jeremy Friesner,3
# 168738,Leon Gaban,3
# 184184,Lenin Raj Rajasekaran,3
# 197546,Daniel,3
# 222908,Daniel Vassallo,3
# 236421,Martin,3
# 242278,uliwitness,3
# 252228,Martin Honnen,3
# 256970,Cary Swoveland,3
# 277023,kellyfj,3
# 285465,TomTom,3
# 296974,glglgl,3
# 388787,Dan D.,3
# 391715,abney317,3
# 447489,fancyPants,3
# 447901,lit,3
# 472883,Joe,3
# 515932,Jeff Gu Kang,3
# 559745,Floern,3
# 575754,Mehdi,3
# 584518,Lundin,3
# 633183,user633183,3
# 648916,Oscar Calderon,3
# 709537,Eugene Beresovsky,3
# 732221,Martin Zikmund,3
# 753341,ApprenticeHacker,3
# 759558,Neil,3
# 807126,Doug Stevenson,3
# 831785,Mosbah,3
# 844416,MBo,3
# 975066,Justin Jasmann,3
# 984823,Joop Eggen,3
# 1037314,Ben,3
# 1081897,D Stanley,3
# 1125910,Dwight,3
# 1128047,Jonah Bishop,3
# 1184717,MrRoth,3
# 1188322,kiranvj,3
# 1237575,Rafael Winterhalter,3
# 1269567,Bogumił Kamiński,3
# 1269732,Stock Overflaw,3
# 1303585,Arshpreet Wadehra,3
# 1306779,jfowkes,3
# 1353296,JoomlaGuy,3
# 1388292,Jacques Gaudin,3
# 1408356,Scrimothy,3
# 1453822,DeepSpace,3
# 1505120,pnuts,3
# 1509264,MT0,3
# 1513933,Laurent LAPORTE,3
# 1597093,Pablo Miranda,3
# 1625187,Evg,3
# 1730895,Kingsley,3
# 1745001,Ed Morton,3
# 1749403,Sajeetharan,3
# 1841760,Pupil,3
# 1841839,DaImTo,3
# 1904146,blueteeth,3
# 1974224,Cristik,3
# 2000823,David Anderson,3
# 2017175,Reza,3
# 2067753,Used_By_Already,3
# 2102956,Pushpesh Kumar Rajwanshi,3
# 2157864,Satyan,3
# 2161778,Slam,3
# 2266098,NeplatnyUdaj,3
# 2310289,Scary Wombat,3
# 2357112,user2357112,3
# 2372064,MrFlick,3
# 2408867,Lukas Kalbertodt,3
# 2413201,Armali,3
# 2458991,bruno,3
# 2571256,cnishina,3
# 2623538,NaDeR Star,3
# 2628879,aris,3
# 2628903,Velimir Tchatchevsky,3
# 2660680,Anto,3
# 2687721,miles_b,3
# 2695448,mad_,3
# 2700344,leftjoin,3
# 2738695,Abdus Salam Azad,3
# 2739684,Islam Assi,3
# 2751596,tbking,3
# 2796058,Mark Wragg,3
# 2826417,Sanjay,3
# 2895156,Krystian Podemski,3
# 2908599,Romeo Ninov,3
# 2929068,Rachid Rhafour,3
# 2988730,Mad Physicist,3
# 3080908,Lee_Dailey,3
# 3091701,KaNa0011,3
# 3103067,Jannik,3
# 3200657,TangoFoxtrotBravo,3
# 3236706,BlueWater86,3
# 3246362,Sam,3
# 3278326,Jarvis The Avenger,3
# 3331892,Vinod Joshi,3
# 3385212,tynn,3
# 3385632,pmar,3
# 3385827,Mohamed-Yousef,3
# 3393308,yorodm,3
# 3412322,Daniel Beck,3
# 3440745,Tsyvarev,3
# 3508471,KhanhSpring,3
# 3545273,Serge Ballesta,3
# 3640844,Laurens,3
# 3731501,estus,3
# 3733783,Rakesh Makluri,3
# 3741589,Quasimodo&#39;s clone,3
# 3742798,Ashwin Valento,3
# 3805124,PhilS,3
# 3915258,skryshtafovych,3
# 3932166,Nitish,3
# 3973676,Bach Lien,3
# 3998255,crazyGamer,3
# 4009182,Aayush Anand,3
# 4014205,Mohsin Aboobacker,3
# 4037220,Andrei Cusnir,3
# 4042267,Graipher,3
# 4049723,Protozoid,3
# 4122872,userfl89,3
# 4325716,al_khalid,3
# 4359926,plieb,3
# 4400060,radrow,3
# 4410330,Yamko,3
# 4428159,Umar Hussain,3
# 4470582,Eslam Nawara,3
# 4478439,Vaneet Kataria,3
# 4604579,Val,3
# 4694994,Kim Kern,3
# 4717755,PeterT,3
# 4749568,LukaszBalazy,3
# 4866865,Gamification,3
# 4932316,Bazingaa,3
# 5086335,amrrs,3
# 5090100,K&#233;vin Giacomino,3
# 5122006,okovko,3
# 5157454,Ori Drori,3
# 5202563,Ivan Stoev,3
# 5202850,ChrisCarroll,3
# 5218761,Kemal Kıvan&#231; Bakdı,3
# 5239030,iGian,3
# 5265513,JonMan08,3
# 5318705,Andrei Vinogradov,3
# 5506730,gazdagergo,3
# 5520794,Vinay Avasthi,3
# 5577765,Rabbid76,3
# 5619511,florian,3
# 5632629,player0,3
# 5772882,Ole V.V.,3
# 5864177,Md.ibrahim khalil,3
# 5871070,Aakash Gandhi,3
# 6060849,Sharvan,3
# 6075331,Bravo Yeung,3
# 6095444,Pravin,3
# 6167855,scsimon,3
# 6220759,Josh Friedlander,3
# 6242681,Mike,3
# 6316508,Leo C,3
# 6343617,Jon Scott,3
# 6375917,TongChen,3
# 6389562,Rasanjana N,3
# 6451573,Jean-Fran&#231;ois Fabre,3
# 6487675,dWinder,3
# 6628028,Raul Karim Sabag Ballesteros,3
# 6663375,Uladzimir Asipchuk,3
# 6779307,Patrick Haugh,3
# 6798994,Fractal,3
# 6882497,Akiner Alkan,3
# 7080630,Richard Gamarra,3
# 7140167,obayral,3
# 7297700,David Browne - Microsoft,3
# 7326738,Ajax1234,3
# 7461381,Mamun,3
# 7617020,Red Bottle,3
# 7635471,Nick Fortescue,3
# 7644199,joseluismurillorios,3
# 7666442,Nilesh Rathod,3
# 7897395,enxaneta,3
# 7901555,Mehrdad Mahdian,3
# 7919626,NTR,3
# 7998591,Kaushik Nayak,3
# 8034839,shizhen,3
# 8073652,s1m0nw1,3
# 8077104,Lex Soft,3
# 8079754,Moe,3
# 8363456,Tom Dee,3
# 8375099,arun kumar,3
# 8398549,Cid,3
# 8427457,TheSprinter,3
# 8477999,Gem Taylor,3
# 8526705,Dacre Denny,3
# 8550140,Khaled Qasem,3
# 8628758,JamesD,3
# 8705432,brian m. carlson,3
# 8720748,nkhar,3
# 8784944,NemoSaltatSobrius,3
# 8798220,Nisharg Shah,3
# 8836232,petronius,3
# 8839621,Adam Małek,3
# 8867131,Dheerendra,3
# 8921612,Artem Trunov,3
# 8952861,boom,3
# 8992563,TehMightyPotato,3
# 9004545,Mubeen Khan,3
# 9060715,Mayuresh Jaiswal,3
# 9078341,Randy Casburn,3
# 9097906,Littlefoot,3
# 9146325,Leo Walker,3
# 9171661,Er Deepak Prabhakar,3
# 9181403,Olamide226,3
# 9277245,Ankish Bansal,3
# 9299259,YOLO,3
# 9331439,sdkcy,3
# 9403259,jordanmannfeld,3
# 9521723,SimonF,3
# 9529505,Thailo,3
# 9553594,Jondiedoop,3
# 9624435,Code Maniac,3
# 9647447,Vanshaj Daga,3
# 9662589,Puneet negi,3
# 9668530,Alex Leo,3
# 9695286,Karan,3
# 9700035,MoazRub,3
# 9722636,Gor Kotikyan,3
# 9758194,JvdV,3
# 9823746,Asif Ghaffar,3
# 9898643,Theo,3
# 10008173,David Maze,3
# 10253094,Robert Dresler,3
# 10389622,akshay patil,3
# 10395392,Vishal Arora,3
# 10423558,Alex Riquelme,3
# 10440834,Piotr Szlagura,3
# 10506082,elgordorafiki,3
# 10511793,Statistic Dean,3
# 10552276,Егор Ересько,3
# 10560512,flyjoe12,3
# 10690958,grill05,3
# 10698741,Dogukan Cavus,3
# 10753504,Quentin,3
# 10785732,Peter Ksenak,3
# 10808674,Alain Merigot,3
# 10809912,Rifat Alptekin &#199;etin,3
# 10858631,Mikev,3
# 10893484,Ashok Patidar,3
# 10899859,Dr. K,3
# 10914443,Mike Zinn,3
# 10915384,Kunal Vohra,3
# 10917479,Adam,3
# 10921202,dunajski,3
# 10921263,AnnaKrogager,3
# 10923627,Talha Israr,3
# 10926329,Aastha Saini,3
# 10927896,ilamaaa,3
# 10930404,G Schunk,3
# 10932034,Alvin Theodora,3
# 10940599,N.Tasikj,3
# 10943621,Swaraj Mahajan,3
# 10944202,Brecht Coghe,3
# 10944314,Unkle Benz,3
# 7432,Bryan Oakley,3
# 10956936,SebSer,3
# 10958596,Alt95,3
# 10959473,Siddharth Patankar,3
# 10960882,markuscosinus,3
# 10960998,Om Prakash,3
# 10952264,thebear8,3
# 9204,Alexey Romanov,3
# 14955,Thilo,3
# 20860,Bill Karwin,3
# 67579,Willem Van Onsem,3
# 471573,trueicecold,2
# 486718,dimpiax,2
# 493729,E4_net_or_something_like_that,2
# 501557,templatetypedef,2
# 504554,hardillb,2
# 560299,Ibu,2
# 560648,Lightness Races in Orbit,2
# 579078,pete,2
# 630496,jemiloii,2
# 635245,Robert Hijmans,2
# 642706,Basil Bourque,2
# 704848,EdChum,2
# 706020,CodeChanger,2
# 712649,Mathias R. Jessen,2
# 729881,Edward Thomson,2
# 746736,Turnip,2
# 790737,Sjors Branderhorst,2
# 797114,Danny Bravo,2
# 821679,Jeffrey Scofield,2
# 822669,Sander De Dycker,2
# 825568,Joseph Silber,2
# 828907,Carlos Uribe,2
# 842327,Zaphod,2
# 862029,JNunez247,2
# 874188,tripleee,2
# 949217,Andy Hoffman,2
# 965146,Shree,2
# 992489,Alexandre Passos,2
# 996787,Rajesh Nasit,2
# 999530,Travis Griggs,2
# 1021703,Jeremy Thille,2
# 1042124,Rahul Kumar,2
# 1051628,Arth,2
# 1055118,doctorlove,2
# 1060423,Manoj,2
# 1064767,Sammitch,2
# 1082008,Kashif Rafique,2
# 1084774,PSkocik,2
# 1087711,Arnaud Christ,2
# 1100107,St&#233;phane Laurent,2
# 1119863,Marcos Casagrande,2
# 1126841,chepner,2
# 1138493,Kefalas Savvas,2
# 1152809,Travis Heeter,2
# 1173192,Manticore,2
# 1175029,Ilya Etingof,2
# 1176601,Aprillion,2
# 1181621,Alex Buyny,2
# 1188513,Mathieu Guindon,2
# 1191259,Frank,2
# 1194694,silicakes,2
# 2653911,Nicolas Pepinster,2
# 2656305,Andy Sug,2
# 2656614,Addison,2
# 2673029,Isma,2
# 2686899,Kenton Varda,2
# 2704032,Vishrant,2
# 2705702,Keijack,2
# 2707792,Andrey Tyukin,2
# 2724940,Baklap4,2
# 2725195,Florent Morin,2
# 2742189,OJ Kwon,2
# 2748412,Franck,2
# 2748967,Umang,2
# 2752265,Jaken Herman,2
# 2809546,Vlad,2
# 2841472,Sai prateek,2
# 2842172,Prashant Patil,2
# 2847222,OtienoJulie,2
# 2906959,Prashant Zombade,2
# 2932476,Boo Berr&#39;ita,2
# 3042759,Tom,2
# 3064889,Beatroot,2
# 3077495,Cindy Meister,2
# 3156333,Crou,2
# 3194005,Derrick Moeller,2
# 3208246,user3208246,2
# 3216427,joanis,2
# 3248312,iamrajshah,2
# 3269832,Vivin K,2
# 3308020,Abbuchu,2
# 3329866,cantuket,2
# 3356376,ali.turan,2
# 3371862,Renaud Tarnec,2
# 3407256,foxyblue,2
# 3416648,DDS,2
# 3461617,Sandro,2
# 3465108,gbellmann,2
# 3466365,Burton Solution,2
# 3477539,rastaman,2
# 3512524,Krzysztof Skowronek,2
# 3534553,vicky92727,2
# 3555700,Rahul,2
# 3568345,Dilshan Liyanage,2
# 3579309,lovasoa,2
# 3629359,T. L.,2
# 3641067,bur&#230;quete,2
# 3644629,Torben,2
# 3690301,JustLearning,2
# 3717691,Jeppe,2
# 3730754,LoicTheAztec,2
# 3742943,LoPiTaL,2
# 3744304,connexo,2
# 3775614,lee-pai-long,2
# 3788176,Andy Turner,2
# 3814777,Dung Ta,2
# 3844458,Pham X. Bach,2
# 3979823,ABOS,2
# 4003419,LukStorms,2
# 4092887,Mauricio Arias Olave,2
# 4124317,ImportanceOfBeingErnest,2
# 4170504,Jenna Leaf,2
# 4217452,Saroj Shrestha,2
# 4224024,Liar,2
# 4242590,Albert,2
# 4262344,Goswin von Brederlow,2
# 4265739,leonardkraemer,2
# 4280242,Jatentaki,2
# 4333359,ALollz,2
# 4350753,Trace,2
# 4357792,AUser,2
# 4379151,Erik Kalkoken,2
# 4386427,4386427,2
# 4387019,Caders117,2
# 4416512,Aron,2
# 4421608,Alexander Kuttig,2
# 4421870,Mako212,2
# 4459617,Hannover Fist,2
# 4465373,Farruh Habibullaev,2
# 4467208,Murat Karag&#246;z,2
# 4470135,yuranos87,2
# 4482269,Wolfack,2
# 4499795,Louis,2
# 4535200,Qirel,2
# 4539709,0m3r,2
# 4577647,Aiden Grossman,2
# 4606040,Fabian K&#252;ng,2
# 4612499,Jean de Lavarene,2
# 4619477,Kiran ,2
# 4681609,Afraz Ahmad,2
# 4700156,Rohit Singh,2
# 4725760,Mohanavel T,2
# 4739488,Flydog57,2
# 4748690,Vebbie,2
# 4755179,Vincent,2
# 4758255,ישו אוהב אותך,2
# 4777984,tgikal,2
# 4781067,PossessWithin,2
# 4782694,NAIT,2
# 4812089,Harro Cyranka,2
# 4857187,Santosh Balaji,2
# 4862445,Richard Smith,2
# 4887159,Ray,2
# 4942439,Average Joe,2
# 4964136,Common Man,2
# 4980651,Siyu,2
# 4996248,John Coleman,2
# 5047996,aschipfl,2
# 5048973,P Burke,2
# 5055895,Ankur Tiwari,2
# 5068574,dentemm,2
# 5076822,pedvaljim,2
# 5089204,Shnugo,2
# 5093961,Steven Spungin,2
# 5138767,BlueFish,2
# 5158077,james.bondu,2
# 5199514,JdeMello,2
# 5223903,Gunjan Raval,2
# 5246885,Alex Mamo,2
# 5246906,nigel222,2
# 5260209,Vinicius Campanate,2
# 5260982,Dave,2
# 5276893,Bass,2
# 5292302,Petter Friberg,2
# 5341306,Imran.Khan,2
# 5356349,Albin Paul,2
# 5369026,Praveen Kumar,2
# 5374924,Ananay Mital,2
# 5381184,BobRun,2
# 5408567,Pullata Praveen,2
# 5427538,Dalendrion,2
# 5464747,dfundako,2
# 5470449,VoidZA,2
# 5485167,yurzui,2
# 5495381,sdcbr,2
# 5499125,Abid Shah,2
# 5567495,Pueue,2
# 5577076,DinoCoderSaurus,2
# 5597680,Cong Nguyen,2
# 5635580,Sotos,2
# 5636775,Ctx,2
# 5641669,Johannes,2
# 5646962,Thomas Kl&#228;ger,2
# 5653015,iOS Lifee,2
# 5696626,Adrian Martin,2
# 5698120,Rex Raphael,2
# 5698672,Sardar Usama,2
# 5723098,Harshal Patil,2
# 5724303,Kosh Very,2
# 5728991,ThunderCat,2
# 5736515,Charles R,2
# 5751378,OmryRo,2
# 5788720,Iain Duncan,2
# 5792244,Dave2e,2
# 5804723,Michał Sadowski,2
# 5820010,Sh_Khan,2
# 5858851,pault,2
# 5871602,Daniel E.,2
# 5883957,J.Bigham,2
# 5891503,reiallenramos,2
# 5897636,Sandeep Menon,2
# 5898696,J-Alex,2
# 5956891,ShreePrakash,2
# 6024220,Daniel Rearden,2
# 6040181,Biagio Festa,2
# 6056930,Dumb,2
# 6066986,Grynets,2
# 6183113,Chanaka Lakmal Weerasinghe,2
# 6196568,shingo,2
# 6207901,Patka07,2
# 6210699,Mauricio Atanache,2
# 6214899,Cường Nguyễn,2
# 6217049,Christian S.,2
# 6235388,Andreas Paech,2
# 6257435,DonMag,2
# 6260170,Chris_Rands,2
# 6261331,Asu,2
# 6276596,Furkan Yurdakul,2
# 6279536,Konstantin Konstantinov,2
# 6350106,Christopher Slater,2
# 6356278,Wimpel,2
# 6371123,G.M.,2
# 6420491,Engmdik,2
# 6428820,Shruti Gupta,2
# 6439799,Karim,2
# 6455968,fstam,2
# 6471139,Pawan Kotak,2
# 6482561,Vladimir Botka,2
# 6530970,Maurits Evers,2
# 6564276,Vijunav Vastivch,2
# 6583674,Katy H.,2
# 6594576,Paul Floyd,2
# 6606090,Mohammad altenji,2
# 6713544,Naween Niroshan,2
# 6728020,Rex,2
# 6729397,Nicolae Maties,2
# 6738015,Compo,2
# 6740036,Vineeth Sai,2
# 6745807,Fzstyle,2
# 6759241,greeble31,2
# 6811411,LotPings,2
# 6831257,sajib,2
# 6832309,Van Romy,2
# 6841875,Alok,2
# 6851825,Jon Spring,2
# 6858150,David Zhang,2
# 6869129,ShaoFeng Shi,2
# 6915690,Vahalaru,2
# 6921491,Sooraj N Raju,2
# 6938822,Max,2
# 6943762,Saurabh Mistry,2
# 7005159,Tom Sun,2
# 7041505,Itay Feldman,2
# 7071415,balzacLeGeek,2
# 7093741,Chris,2
# 7128934,d.b,2
# 7132550,Michał Turczyn,2
# 7141506,Mikhail Stepanov,2
# 7184515,mccandar,2
# 7207514,Deiv,2
# 7240059,Jennifer,2
# 7253829,waymobetta,2
# 7258443,deleaf,2
# 7294145,S. Imp,2
# 7308667,Juan Carlos Ibarra,2
# 7318615,Yongkang Zhao,2
# 7321942,gboeing,2
# 7334409,Sagar Bhut,2
# 7373817,Ramesh Bathini,2
# 7460777,Leo Liu-MSFT,2
# 7481509,pgupta,2
# 7530691,Adil Ayoub,2
# 7541294,Armin,2
# 7647026,SQL_M,2
# 7658533,Unhandled Exception,2
# 7682424,hoythan,2
# 7715095,xyz,2
# 7720160,Krishna sheladiya,2
# 7734732,Dmitry Demin,2
# 7789378,BlindSniper,2
# 7792004,Arjun Patel,2
# 7799677,thecruisy,2
# 7800479,Keshav Sharma,2
# 7825803,Moritz,2
# 7871804,nycrefugee,2
# 7906032,Rajesh Babu,2
# 7910059,Hemme02,2
# 7925166,Exprator,2
# 7927200,Niloy Rashid,2
# 7932273,Sociopath,2
# 7940614,assembly.jc,2
# 7959882,Maugrim,2
# 7961905,MatrixTai,2
# 7982963,Moaaz Bhnas,2
# 8034736,Sreekanth G,2
# 8039266,jhoover4,2
# 8043636,Sina Safarabadi,2
# 8043734,sameeksha sahib,2
# 8067350,Val Geyvandov,2
# 8068625,Henry Woody,2
# 8105437,dmcgrandle,2
# 8117146,Avi,2
# 8139278,Allaye,2
# 8169091,mvs,2
# 8193698,Dharan,2
# 8205133,Andrew21111,2
# 8206705,H. Ross,2
# 8215120,Fayer,2
# 8235971,Shamrai Aleksander,2
# 8283102,Rohit,2
# 8298909,Ben P.,2
# 8329213,cph_sto,2
# 8368621,illuminarch,2
# 8371153,elraphty,2
# 8381946,Justin Bertram,2
# 8382008,M. Wojcik,2
# 8389003,arg0naut,2
# 8426532,Murat Tutumlu,2
# 8427065,Bhaskar Dhariyal,2
# 8437694,IvanS95,2
# 8476830,Partho63,2
# 8577887,Vikash Chinnari,2
# 8578679,Krantz,2
# 8599026,Muhammed YILMAZ,2
# 8618934,raf18seb,2
# 8692657,Mariia Mykhailova,2
# 8791066,Tom,2
# 8801730,Morhaf Shamia,2
# 8806617,Adam Bukowiecki,2
# 8819461,Maheshwar Kuchana,2
# 8841057,Bob Smith,2
# 8866606,Stefan Becker,2
# 8867311,Lee_MSFT,2
# 8870196,Shaman,2
# 8904424,Piyush Zalani,2
# 8930031,Max Wiederholt,2
# 8986917,Sanath Kumar,2
# 9014308,kunif,2
# 9018835,Иван Васильев,2
# 9036204,UncleBen,2
# 9044051,Arun Rajagopal,2
# 9071502,mweirauch,2
# 9079096,saman aliniazare,2
# 9135351,2kFerd,2
# 9165678,Radoslav Mitev,2
# 9199778,Amit Panasara,2
# 9212519,Rajkumar,2
# 9250153,Alex.Wei,2
# 9290986,Chronocidal,2
# 9291201,Anusha Subashini,2
# 9303401,Monica Acha,2
# 9312233,Mukul Kumar Jha ,2
# 9325817,Vignesh Bayari R.,2
# 9328117,Shahid Hussain Abbasi,2
# 9331166,Udhav Sarvaiya,2
# 9381809,Ariz,2
# 9389998,Mohan M,2
# 9401038,sergaz-msft,2
# 9414803,kurtisvg,2
# 9455299,bupt_ljy,2
# 9455659,Joy Wang,2
# 9497965,NaT3z,2
# 9514282,Anindyo Bose,2
# 9556919,dongi,2
# 9614249,Increasingly Idiotic,2
# 9629503,Jeppe Spanggaard,2
# 9632969,Adam Stawarek,2
# 9714791,Mehrdad Dowlatabadi,2
# 9731167,Galo Torres Sevilla,2
# 9753100,Francis Katalinic,2
# 9758922,nuric,2
# 9773937,Charles Xu,2
# 9783864,David Edel,2
# 9798989,Abhisar Tripathi,2
# 9799857,Firu,2
# 9830756,Kamil D,2
# 9848076,Fy Z1K,2
# 9892073,aurelius,2
# 9926721,FUNNYDMAN,2
# 9928809,mk_sta,2
# 9940803,pascal sanchez,2
# 9949370,2rahulsk,2
# 9968486,Pilan,2
# 9994312,Alex Kamaev,2
# 9996381,Nick,2
# 10021789,Pranitha jemmalla,2
# 10077925,Wojciech Chmiel,2
# 10093008,Star Lut,2
# 10118270,Mike,2
# 10130916,Harshit,2
# 10134447,Jason Is My Name,2
# 10157630,mounirboulwafa,2
# 10182897,Ashish,2
# 10185344,Arshiya Khanam,2
# 10185816,Ivan Yang,2
# 10204945,Vipul Chauhan,2
# 10206540,Anil Agrawal,2
# 10237950,Maxim Fedorov,2
# 10242854,guy,2
# 10257708,Zhonghao Cao,2
# 10268067,steve moretz,2
# 10269812,siva perumal,2
# 10317684,Ricky Mo,2
# 10335421,Ali Hussam,2
# 10342880,kristina,2
# 10347490,Tygo,2
# 10363509,Srikanth Vagga,2
# 10388629,pizza static void main,2
# 10401731,Shivasagar,2
# 10411602,Blaze,2
# 10413416,Infern0,2
# 10420039,Hiroki,2
# 10422370,cl0ud,2
# 10428268,markorial,2
# 10444813,a.bajorinas,2
# 10451543,Viren Panchal,2
# 10471480,Mangaldeep Pannu,2
# 10517916,Igor K.,2
# 10524205,Bsquare,2
# 10535037,sashavol,2
# 10553976,Charles Landau,2
# 10554174,Amit Bhoyar,2
# 10598286,MR.Robot,2
# 10599951,Anoop Rajta,2
# 10618540,Paritosh Singh,2
# 10629724,Python Newb,2
# 10709148,Emmett Corman,2
# 10720467,Jaidee,2
# 10721592,biruk1230,2
# 10729151,Kurose,2
# 10799102,Vitor Kevin,2
# 10839366,Pradnya Choudhari,2
# 10851162,Dismi Paul,2
# 10862525,nyu.exe,2
# 10865921,Manu Bhardwaj,2
# 10866052,InterviewSortout,2
# 10867487,Echoinacup,2
# 10875536,Adersh,2
# 10883274,Diksha Bhargava,2
# 10890157,Erich,2
# 10890905,amira ahmed,2
# 10896999,krishna,2
# 10897835,Alex,2
# 10902048,J. Davis,2
# 10912474,alanpollenz,2
# 10917348,Brueni,2
# 10919370,Marcel Preda,2
# 10925281,dnacarlos,2
# 10926702,Henrik Erstad,2
# 10927337,Zhangnan JIANG,2
# 10936865,taka,2
# 10937160,Daxa Varsani,2
# 10939204,Traian GEICU,2
# 10943352,Hưng Quyền Chềnh,2
# 10948983,D.Janssen,2
# 10951070,R. Uziel,2
# 10952119,kleisauke,2
# 10953346,A. Chang,2
# 10954216,Lakhani Aliraza,2
# 10954349,JosemyAB,2
# 10954541,n.sil,2
# 10957523,Dragos matianu,2
# 10958042,Marwane Boudriga,2
# 10958049,nkincy,2
# 10958549,binford2k,2
# 10958763,David Keegel,2
# 10958940,Vulture,2
# 10959706,Paul H,2
# 10959853,Abhay Kumar,2
# 10960211,Samuel,2
# 10960267,ahmed,2
# 10961392,G&#252;nkut Ağabeyoğlu,2
# 10961493,fratardi,2
# 10961587,WatchMyApps Lab,2
# 10962679,Dmitry,2
# 4411,Jagger,2
# 7231,Dave Cross,2
# 11265,Matthew Trevor,2
# 14122,Charles Duffy,2
# 14660,Schwern,2
# 15168,Jonathan Leffler,2
# 22656,Jon Skeet,2
# 27302,Daniel H,2
# 34092,mjwills,2
# 48910,Meta-Knight,2
# 49811,Eugene Petrenko,2
# 50617,Employed Russian,2
# 66696,Allan Bowe,2
# 71245,Leon Radley,2
# 80911,Evert,2
# 82586,James,2
# 85785,mythz,2
# 89766,George Profenza,2
# 99256,Martin Vseticka,2
# 101087,NineBerry,2
# 105904,Andrew Janke,2
# 108205,jsbueno,2
# 113325,Schnouki,2
# 128165,Gabriele Petrioli,2
# 128511,gman,2
# 130288,gojomo,2
# 132438,Felipe Hoffa,2
# 134554,John Bode,2
# 135589,Jesper,2
# 143475,Peter Thomas,2
# 147024,yole,2
# 148844,Chloe,2
# 155187,warrenm,2
# 157957,IMSoP,2
# 166168,Extelliqent,2
# 182660,SergGr,2
# 187690,AnT,2
# 205997,Arash Milani,2
# 225016,Matthew L Daniel,2
# 228755,Azhar,2
# 251873,IanCaz,2
# 267693,Ken Ratanachai S.,2
# 268396,user268396,2
# 278149,Kurucu,2
# 306838,wodka,2
# 310726,martin,2
# 320087,Niraj Sonawane,2
# 328193,David,2
# 330315,a_horse_with_no_name,2
# 332059,Dmitry Streblechenko,2
# 333340,Synchro,2
# 340457,Bytemain,2
# 375148,deerawan,2
# 399908,Martin Hennings,2
# 402366,Paulo Morgado,2
# 417899,cyberfly,2
# 421195,paulsm4,2
# 446279,vc 74,2
# 447970,teylyn,2
# 451601,James K. Lowden,2
# 453673,Nav,2
# 1143,Quibblesome,1
# 1288,Bill the Lizard,1
# 1338,Jason,1
# 2820,Onorio Catenacci,1
# 3121,Bruce Johnston,1
# 4035,Sung Kim,1
# 5715,Shane Bauer,1
# 7404,belwood,1
# 10116,Larry OBrien,1
# 10888,Leonard,1
# 11635,Ruben Bartelink,1
# 12958,justin.m.chase,1
# 13422,Zan Lynx,1
# 14104,epascarello,1
# 15687,Andrew Ingram,1
# 15809,Mecki,1
# 17323,Rene,1
# 18591,Louis Jacomet,1
# 23321,pgl,1
# 23633,Bradley Grainger,1
# 24267,mhenry1384,1
# 25324,pmg,1
# 30006,John,1
# 30038,Vlad Bezden,1
# 33252,Doug Currie,1
# 37110,BeWarned,1
# 40851,Simon Wright,1
# 44014,Zargony,1
# 47672,0x49D1,1
# 49554,jneira,1
# 50476,Bart Kiers,1
# 50543,Julian Reschke,1
# 50711,rball,1
# 54929,AhmetB - Google,1
# 61126,Jerry Sha,1
# 70140,Moe Sisko,1
# 79109,Vimvq1987,1
# 86646,Eric Dahlvang,1
# 86967,nobar,1
# 88122,jwilleke,1
# 90527,outis,1
# 91218,Degan,1
# 92359,InverseFalcon,1
# 94977,Jason Orendorff,1
# 97076,Andrew Sledge,1
# 98062,Rocky Luck,1
# 103577,lazysoundsystem,1
# 104891,CrazyCoder,1
# 105755,Niels,1
# 106909,Mark van Straten,1
# 107744,spencer7593,1
# 111337,scottheckel,1
# 113730,RB Davidson,1
# 114626,Eyal Roth,1
# 115145,CommonsWare,1
# 120753,Babak Naffas,1
# 120955,StriplingWarrior,1
# 120982,ObjectMatrix,1
# 128792,David Kocher,1
# 130501,Gaotter,1
# 134204,Panagiotis Kanavos,1
# 137626,FelipeAls,1
# 146325,APC,1
# 148496,Jens T&#246;rnell,1
# 149341,duskwuff,1
# 152948,hobbs,1
# 156142,ChaosPandion,1
# 157247,T.J. Crowder,1
# 160673,Neil Mitchell,1
# 161008,Robin,1
# 161628,Rohit Banga,1
# 162137,Richard Friend,1
# 164835,Kent,1
# 165216,PaulMcG,1
# 166389,TBBle,1
# 168179,MarqueIV,1
# 169095,russellpierce,1
# 170961,matiit,1
# 171318,hek2mgl,1
# 171456,Zim,1
# 177498,ubershmekel,1
# 178758,RonU,1
# 179583,natevw,1
# 182668,Pointy,1
# 183910,Bernhard Vallant,1
# 183934,ErikEJ,1
# 185647,Squirrel,1
# 190701,Piers Karsenbarg,1
# 191708,nvogel,1
# 193178,Rolf Kristensen,1
# 200898,Moss,1
# 202739,fepiv,1
# 211116,Spacedman,1
# 216513,nathanvda,1
# 218196,Felix Kling,1
# 218725,Zabs,1
# 219159,Seva Alekseyev,1
# 223942,Kilanash,1
# 225020,Jaba,1
# 227863,stephenmurdoch,1
# 229939,erict,1
# 231299,beerboy,1
# 231762,kkrugler,1
# 232794,Sardathrion,1
# 234590,Francis Gagn&#233;,1
# 236222,Jay,1
# 236247,demongolem,1
# 236415,Jeff,1
# 239582,lupchiazoem,1
# 239879,Shamoon,1
# 242042,Archimedes Trajano,1
# 245646,Ed of the Mountain,1
# 250248,Player1st,1
# 250517,Grzegorz Grzybek,1
# 255673,User.Anonymous,1
# 257182,RobG,1
# 259017,dougalg,1
# 260122,clacke,1
# 266143,CodeCaster,1
# 274332,usualexpat,1
# 279782,roryhewitt,1
# 283895,tgolisch,1
# 288405,Mattie,1
# 290339,akond,1
# 294884,Fattie,1
# 296677,Terrance,1
# 298143,gasche,1
# 298225,Eric Postpischil,1
# 298371,cyraxjoe,1
# 301513,Qiulang,1
# 306047,snorbi,1
# 312440,Naomi,1
# 315168,Mikko Ohtamaa,1
# 318414,simonalexander2005,1
# 318673,sabujp,1
# 318921,Neil Bartlett,1
# 321491,Mitten.O,1
# 322863,aef,1
# 322995,lardymonkey,1
# 324449,Max Gasner,1
# 325209,AA.,1
# 328036,Dustin Ingram,1
# 328817,Sam,1
# 335858,dasblinkenlight,1
# 336378,Alex AIT,1
# 343355,Paul Shealy,1
# 344887,JERKER,1
# 348185,akaspick,1
# 348384,Feldur,1
# 350613,Robin Moffatt,1
# 351508,Jamie R Rytlewski,1
# 353567,Munim,1
# 353714,Marcodor,1
# 362536,Brad,1
# 363751,supercat,1
# 367332,DarthFennec,1
# 368034,Carlos Martins,1
# 368105,Aron,1
# 369428,Joubarc,1
# 369446,Michael Shopsin,1
# 371045,Jon Bates,1
# 372172,Koala Yeung,1
# 372239,Toto,1
# 379897,R..,1
# 380384,ja72,1
# 389289,zvone,1
# 392025,Aurel B&#237;l&#253;,1
# 395202,Adrian Shum,1
# 395255,Asdfg,1
# 396705,Grebets Kostyantyn,1
# 397793,Muhamad Bhaa Asfour,1
# 402053,JBaruch,1
# 402281,Feuermurmel,1
# 402632,tylerthemiler,1
# 405051,Andrew,1
# 406691,Pavel Stehule,1
# 410823,Skarab,1
# 411806,akkonrad,1
# 412080,Maxim Egorushkin,1
# 414415,Ilias Karim,1
# 415268,Rexb,1
# 419261,humblePilgrim,1
# 424111,Co7e,1
# 424604,akkdio,1
# 432844,Julien Nioche,1
# 436776,robocat,1
# 445425,chris neilsen,1
# 446594,DarkBee,1
# 448675,Glade Mellor,1
# 452100,asdr,1
# 452775,Lii,1
# 454705,Navin Peiris,1
# 463319,Twisty,1
# 474189,Duncan Jones,1
# 474349,Hong Ooi,1
# 482262,SquareRootOfTwentyThree,1
# 482406,plambert,1
# 488019,Daniel Garc&#237;a Baena,1
# 488905,wllmsaccnt,1
# 490170,Jamie,1
# 491605,Nathan,1
# 495455,Jeremy Thompson,1
# 496289,Kashyap,1
# 497600,lhk,1
# 505088,David Heffernan,1
# 507738,MC Emperor,1
# 516754,d4c0d312,1
# 517003,Tevya,1
# 528136,Dima Vishnyakov,1
# 529630,Dunes,1
# 537259,william tell,1
# 540873,Thomas Jungblut,1
# 540955,myf,1
# 541016,Frank Schlegel,1
# 545499,Daniel_Madain,1
# 545637,Apalala,1
# 549372,Martin Zeitler,1
# 551919,Ray,1
# 556613,Nick,1
# 556899,stgatilov,1
# 563231,David Metcalfe,1
# 563394,Ryan,1
# 567854,Ijas Ameenudeen,1
# 570763,Arda,1
# 579731,Emmanuel,1
# 580083,Daniel Langr,1
# 584018,user584018,1
# 592308,James Woolfenden,1
# 604530,pkhlop,1
# 607970,Mike Goodwin,1
# 611545,Ross Bush,1
# 619218,Jessica Chiang,1
# 623041,eggyal,1
# 625403,amalloy,1
# 629032,dpb,1
# 631764,Buttle Butkus,1
# 634146,ashkufaraz,1
# 636509,TommyN,1
# 636626,Nils Werner,1
# 637853,Thomas,1
# 647828,L&#233;o Germond,1
# 650428,Aspix,1
# 652031,sirramongabriel,1
# 652669,GG.,1
# 663028,prusswan,1
# 670339,Marc Talbot,1
# 674039,wim,1
# 677983,ophychius,1
# 678910,Shirkan,1
# 679824,Krishnan Mahadevan,1
# 697154,Yoshi,1
# 697213,TruckDriver,1
# 713983,Roland W,1
# 717267,Eduardo Cuomo,1
# 717898,Andrew Lazarus,1
# 720822,Corey,1
# 724176,Hugo,1
# 728358,gurooj,1
# 728617,Jeba Prince,1
# 728812,Michael Hunger,1
# 735226,Johannes Klau&#223;,1
# 757508,luschn,1
# 763085,AntPachon,1
# 763355,MoDJ,1
# 764040,maasg,1
# 765939,t3chi3,1
# 767535,ammcom,1
# 767625,Anjana Silva,1
# 767903,Andrew W. Phillips,1
# 770938,mopsled,1
# 771848,alecxe,1
# 776515,Luis,1
# 777689,PeterT,1
# 778560,Aacini,1
# 779527,Scriptable,1
# 786020,Poik,1
# 786593,Mr. Me,1
# 787757,sparebytes,1
# 796808,Jim,1
# 798788,roberthuttinger,1
# 801646,Max,1
# 803008,Joris Ros,1
# 806889,ben_nuttall,1
# 811240,Mike,1
# 819019,Taterhead,1
# 819843,Motlicek Petr,1
# 823247,walterhuang,1
# 825190,Alessandro Cosentino,1
# 831800,Taersious,1
# 832273,Ulrich Dangel,1
# 833881,kungphu,1
# 835883,j2emanue,1
# 836189,CountZachula,1
# 837530,Sa&#39;ad,1
# 840772,mahesh madhusudanan,1
# 841424,truf,1
# 842935,dani herrera,1
# 847950,namelivia,1
# 848253,PerracoLabs,1
# 851737,schlamar,1
# 855443,user855443,1
# 861352,LemonLion,1
# 861807,Moebius,1
# 864696,Ross Presser,1
# 866989,kanitw,1
# 869621,Kevin Gosse,1
# 869736,Louis Wasserman,1
# 870122,perissf,1
# 892433,Andrew,1
# 896981,magiccrafter,1
# 901973,thundertrick,1
# 903124,Fabian Bigler,1
# 909908,Justin Rowe,1
# 910210,user910210,1
# 911419,Suncatcher,1
# 916382,Gerard,1
# 918910,jib,1
# 927172,AndroidNoobie,1
# 927493,JF Meier,1
# 928611,Jacek Kwiecień,1
# 939364,Gallaecio,1
# 939630,Tpojka,1
# 939860,Erwin Brandstetter,1
# 939870,Ayub,1
# 941397,Superdooperhero,1
# 953482,Kevin,1
# 956415,Jakob Eriksson,1
# 957280,keyoxy,1
# 957822,Nate Ingles,1
# 958373,Stephane,1
# 958464,Gianluca Ghettini,1
# 978501,Sridhar,1
# 979052,Lissy,1
# 980550,lurker,1
# 991609,Neville Nazerane,1
# 992667,yrral86,1
# 993851,bluelemonade,1
# 996606,lowleveldesign,1
# 999082,Jazimov,1
# 1001889,Shine,1
# 1005939,user1005939,1
# 1006821,Vivian Lobo,1
# 2725109,user2725109,1
# 2726157,rrger,1
# 2747287,Ryan Schlueter,1
# 2750743,Artur  Klesun,1
# 2754599,Thomas,1
# 2756832,Kandy,1
# 2757828,Litvin,1
# 2764255,Nikos Paraskevopoulos,1
# 2765783,LynxZh,1
# 2768007,radioman,1
# 2776566,Raphael,1
# 2787784,Hazhir,1
# 2790482,Reasurria,1
# 2790621,xMRi,1
# 2795953,MQuiggGeorgia,1
# 2801588,Ismoil  Shifoev,1
# 2814241,HappyCoder,1
# 2818351,Kashyap MNVL,1
# 2832208,Mikołaj Mularczyk,1
# 2834847,ag.pronto,1
# 2835971,Michele,1
# 2837443,Alex.F,1
# 2838451,Sanjay Bhimani,1
# 2844319,AbraCadaver,1
# 2865757,Zefick,1
# 2866919,RastoStric,1
# 2867882,Shenanigator,1
# 2886883,Eric Harris,1
# 2889471,sudheerchamarthi,1
# 2891324,nessuno,1
# 2919531,ASK,1
# 2935350,Vad  Goro,1
# 2938861,farax,1
# 2956272,dyukha,1
# 2968650,cristallo,1
# 2973534,danemacmillan,1
# 2986153,Joe,1
# 3012916,nekperu15739,1
# 3012961,Dmitry Weiner,1
# 3017216,Jainik,1
# 3024933,just,1
# 3027266,Wernfried Domscheit,1
# 3029422,Ionut,1
# 3034938,Pushpendra Kumar,1
# 3041435,Gufran Hasan,1
# 3046669,BRDroid,1
# 3048967,ScrapCode,1
# 3049344,DmitryZyr,1
# 3049394,TVK,1
# 3065611,user3065611,1
# 3067819,thedaddyfob,1
# 3069232,user3069232,1
# 3072350,Chris Catignani,1
# 3072640,HouseCat,1
# 3075533,mohsenmadi,1
# 3090068,Yuki Inoue,1
# 3099185,Bhuro,1
# 3101511,mindo,1
# 3104312,anuragb26,1
# 3110834,Reza Aghaei,1
# 3122406,Bhavik Modi,1
# 3124227,Axel P,1
# 3127347,user3127347,1
# 3130281,Hristiyan Dodov,1
# 3133418,nick zoum,1
# 3134251,Lafexlos,1
# 3142365,Moctar Haiz,1
# 3151114,LetoThe2nd,1
# 3158028,Soubriquet,1
# 3160475,Itamar Haber,1
# 3160561,maxkonovalov,1
# 3163557,ZbynekZ,1
# 3167221,jelhan,1
# 3169096,Christian G Fritsch,1
# 3178962,clockworknet,1
# 3183946,sme,1
# 3192693,Monster Brain,1
# 3195477,DaveInCaz,1
# 3207222,mrcalvin,1
# 3214824,user3214824,1
# 3218692,Yeldar Kurmangaliyev,1
# 3228483,grenzbotin,1
# 3233770,John Halsey,1
# 3235610,user3235610,1
# 3240681,&#228;lёx&#246;l&#252;t,1
# 3242146,Jeff Garrett,1
# 3247017,pazitos10,1
# 3248279,eyeslave,1
# 3257404,Kevin,1
# 3266847,Benjamin W.,1
# 3271820,SammuelMiranda,1
# 3277386,TreffnonX,1
# 3278320,Josh,1
# 3279496,nelek,1
# 3282056,rcgldr,1
# 3284624,D.B.,1
# 3286903,WeSee,1
# 3288766,Fixitrod,1
# 3298688,FaithoftheFallen,1
# 3304145,rvertigo,1
# 3307985,Jason Johnston,1
# 3336423,jpo38,1
# 3339758,varlogtim,1
# 3339907,shhdharmen,1
# 3346628,pomo,1
# 3348804,SavageStyle,1
# 3350224,Andrei Tanana,1
# 3352895,user3352895,1
# 3355476,Codor,1
# 3365425,Majid.r,1
# 3365923,Philip Johnson,1
# 3370924,lex,1
# 3379867,coolbreeze,1
# 3381874,DevRajneesh,1
# 3385238,twill,1
# 3391727,Min Thein Win - Jack Liam,1
# 3391860,Dudim,1
# 3399654,Joseph Reeve,1
# 3407920,erdinc,1
# 3421595,zach.winter,1
# 3423025,marienbad,1
# 3429596,Tobias,1
# 3431869,Vamsi Prabhala,1
# 3436775,Ozesh,1
# 3437897,Ghulam Akbar,1
# 3441504,Cashbee,1
# 3442256,Ken4scholars,1
# 3455464,ocrampico,1
# 3456812,markaaronky,1
# 3457707,Xenon,1
# 3458411,user3458411,1
# 3463844,EstebanGarciaAlonso,1
# 3464370,user3464370,1
# 3468139,jainashish,1
# 3468448,rca,1
# 3472014,shawn,1
# 3475381,Gaurav Sehgal,1
# 3481924,Keyrad,1
# 3487732,Akintunde,1
# 3505695,HERE Developer Support,1
# 3519280,Efe Budak,1
# 3521013,Michael Rogers,1
# 3522182,ali-star,1
# 3522957,Eriks Klotins,1
# 3524613,GAEfan,1
# 3527297,Gustav,1
# 3531215,Jiren Jin,1
# 3536236,Martin,1
# 3542813,Bank,1
# 3546858,DevRok,1
# 3547262,progfou,1
# 3547485,Kinght 金,1
# 3555775,Balaji731,1
# 3565132,Haris Bouchlis,1
# 3566056,user3566056,1
# 3568245,ekans,1
# 3586022,user3586022,1
# 3599970,Timmy_A,1
# 3601130,Sagar Morakhia,1
# 3609571,Fabian Hueske,1
# 3611989,Rory,1
# 3621421,Nikita Kniazev,1
# 3624084,Badger,1
# 3625215,MyTwoCents,1
# 3636099,Murali,1
# 3636601,Jens,1
# 3636822,tomasulo,1
# 3647115,Danlexo,1
# 3648693,NoobTW,1
# 3650737,g__n,1
# 3661007,Candor,1
# 3669650,flydyk,1
# 3674263,CodeSpent,1
# 3679147,RADO,1
# 3689450,vlaz,1
# 3698762,Stefan,1
# 3702377,Benyamin Jafari,1
# 3707720,Dylan,1
# 3713777,titsitits,1
# 3715778,koryakinp,1
# 3728639,Chathura Buddhika,1
# 3734222,incBrain,1
# 3737009,Granitosaurus,1
# 3753875,Hbargujar,1
# 3756408,Darish,1
# 3760553,user3760553,1
# 3761434,colby-ham,1
# 3761628,eol,1
# 3765705,cdf1982,1
# 3770853,gsus,1
# 3782865,zohar.kom,1
# 3790546,Pablo,1
# 3794812,Nicholas Tower,1
# 3795043,findusl,1
# 3805062,bayrinat,1
# 3813942,user3813942,1
# 3824723,CoMartel,1
# 3826641,karikevinod,1
# 3829417,GregH,1
# 3829426,hlagos,1
# 3840100,user3840100,1
# 3840840,Sebastian Brosch,1
# 3841872,Keith M,1
# 3850405,Ogglas,1
# 3850730,Sabir Khan,1
# 3857354,Preethi,1
# 3881716,David Auvray,1
# 3885491,Falco Winkler,1
# 4367683,Machado,1
# 4375327,Amessihel,1
# 4378740,chakeda,1
# 4381487,gilch,1
# 4384775,McDonal_11,1
# 4391450,AxelH,1
# 4395287,David Jaw Hpan,1
# 4395464,CRR,1
# 4406395,Bill Bliss - MSFT,1
# 4408092,binway,1
# 4416098,bspeagle,1
# 4430593,Jason Heithoff,1
# 4437417,Gasp0de,1
# 4441547,Aaron Franke,1
# 4442610,Anders Skov,1
# 4449159,Prashant Gosai,1
# 4453737,Mohideen ibn Mohammed,1
# 4455643,Negin Basiri,1
# 4457367,Lango,1
# 4466695,Gregor Eesmaa,1
# 4467571,Luka Dumančić,1
# 4481312,marmeladze,1
# 4481670,Andrea Di Cesare,1
# 4482132,ketan jain,1
# 4482249,Pankaj Cheema,1
# 4488105,paqmo,1
# 4497050,alistaire,1
# 4497941,Learner,1
# 4499941,Peter Maydell,1
# 4501966,Apurba Pandey,1
# 4506140,Jude Niroshan,1
# 4515114,Eelco van Vliet,1
# 4518274,Thomas Dickey,1
# 4531283,IgorM,1
# 4540376,Jure Malovrh,1
# 4549682,wordsforthewise,1
# 4563497,ILYAS_Kerbal,1
# ...
# 7606764,Andronicus,1
# 7607190,June7,1
# 7630584,Fallenour,1
# 7643821,Ilya Miroshnichenko,1
# 7648599,Davide,1
# 7649582,Dhanshri,1
# 7649668,Kachopsticks,1
# 7654215,seuling,1
# 7655391,Sahil Singla,1
# 7655541,Julien van der Kluft,1
# 7655889,mbn217,1
# 7658366,Vivian Mascarenhas,1
# 7665208,Raghav,1
# 7666951,Alan Mac Cormack,1
# 7673116,Nikolay Gogol,1
# 7677793,DeWil,1
# 7681248,Jasper,1
# 7682257,Suraj Vaishnav,1
# 7684630,leej3,1
# 7694507,Lew Keyang,1
# 7698222,Haseeb Warriah,1
# 7716341,zetawars,1
# 7718215,80x24,1
# 7727181,Lucas Weyne,1
# 7737942,Sanket Shinde,1
# 7743313,Roshan,1
# 7750274,Akshaya Natarajan,1
# 7757215,Joel,1
# 7759377,Tim Robinson,1
# 7761936,aLT,1
# 7763544,Kiran Kanzar,1
# 7768569,Mehul Prajapati,1
# 7771253,froggomad,1
# 7774623,Jbrown,1
# 7783514,Kutay B. Sezginel,1
# 7783718,Abhay Koradiya,1
# 7792662,Kalana Demel,1
# 7794044,Rogelio Sanchez,1
# 7801331,mudassar raza,1
# 7805363,Programming-Lover,1
# 7808468,Mark Denom,1
# 7816085,Alex Edwin Velez,1
# 7818369,Przemo,1
# 7820512,Armen Chilingaryan,1
# 7829826,Daniel Eduardo Delgado Diaz,1
# 7831743,unni krishna,1
# 7844946,Ervin Kalemi,1
# 7848471,Dishant Kawatra,1
# 7850051,Karnan Muthukumar,1
# 7850499,Sherwin Chen,1
# 7852833,tk421,1
# 7855474,Kuiken,1
# 7858504,Robert Nishihara,1
# 7874223,Alizadeh118,1
# 7883067,Mark Nunes,1
# 7900036,John,1
# 7900610,tvankith,1
# 7900853,rvilla,1
# 7915207,Balasubramaniam,1
# 7918714,Filip Młynarski,1
# 7925650,Justin Scofield,1
# 7926640,stensal,1
# 7942000,Stackedo,1
# 7946593,h.p.kumar,1
# 7948152,Kunvar Singh,1
# 7952101,Vineet Jain,1
# 7960551,我零0七,1
# 7960986,Rodriguez David,1
# 7964299,Naveen,1
# 7974120,Nordin,1
# 7978419,elismm,1
# 7991267,Anna,1
# 7996668,krazors,1
# 8003269,Sandeep Kumar,1
# 8004593,lagripe,1
# 8019379,Lucas Raphael Pianegonda,1
# 8021933,Neeraj Kumar,1
# 8039762,cgsdfc,1
# 8055497,lodb,1
# 8080957,Rupesh Goud,1
# 8081373,ghazi,1
# 8093318,michael beale,1
# 8108352,Gianfrancesco Aurecchia,1
# 8110010,Finley,1
# 8111332,Teodor O.,1
# 8114716,Rehmanali Momin,1
# 8126219,JM_,1
# 8129727,Santosh Singh,1
# 8160252,Zouh,1
# 8167810,Curiousdeveloper,1
# 8184112,Daniel,1
# 8188569,DoctorAgon,1
# 8192960,7bebMrto,1
# 8194089,Chamila Maddumage,1
# 8198946,Jay Gong,1
# 8211528,Hooman Bahreini,1
# 8217625,Jeff Groh,1
# 8221046,supertramp,1
# 8222907,James,1
# 8228491,user127091,1
# 8237324,al_sweets,1
# 8240311,Dalibor Adamec,1
# 8258222,helospark,1
# 8261024,Olafant,1
# 8267822,mkkr1009,1
# 8279183,Walid Natat,1
# 8284219,Gopesh Pandey,1
# 8286969,kulwinder singh,1
# 8294830,Learner,1
# 8295847,Tan,1
# 8300135,SpghttCd,1
# 8303489,Muhammad Altabba,1
# 8304235,Rakesh Kunwar,1
# 8304429,Michael Arbib,1
# 8306384,Mayank Gupta,1
# 8316315,Florian Weimer,1
# 8316351,BqNqNNN,1
# 8324502,nyulan,1
# 8326936,Karthick,1
# 8332030,Bastian,1
# 8335769,Jagrut,1
# 8337421,Anam Nizami,1
# 8356801,Horia,1
# 8357634,Alb,1
# 8365439,Valerii,1
# 8366499,divibisan,1
# 8368823,Ranjith eswaran,1
# 8368980,LI ZHE,1
# 8378846,Joe,1
# 8382633,Santiago Capobianco,1
# 8394265,R&#233;mi Rousselet,1
# 8416169,KikeSP,1
# 8418842,Israel Peck,1
# 8423446,Xavier Issac,1
# 8425145,BT101,1
# 8429046,Govan,1
# 8437263,Sheng-Jr Chen,1
# 8442930,Rahul Ruikar,1
# 8446131,Impulse,1
# 8447312,emrepun,1
# 8449239,Jabir ,1
# 8449629,Z.Lin,1
# 8468264,d_kennetz,1
# 8483092,yasin hayal,1
# 8494034,Berni,1
# 8515291,curious.netter,1
# 8522675,Zoro-Zen,1
# 8534008,GBlodgett,1
# 8537847,aevin,1
# 8542346,H.S.,1
# 8557668,Dmitri Veselov,1
# 8564487,Ayan Banerjee,1
# 8567819,Bucq,1
# 8573781,Abhishek Gupta,1
# 8583393,markus,1
# 8583496,Alexey Shrub,1
# 8594750,Chris H.,1
# 8599038,3xGuy,1
# 8616823,Jonny,1
# 8617118,Drew,1
# 8618875,android,1
# 8648994,Eymeric G,1
# 8649393,Andrey Nikolov,1
# 8650422,Gian Gomen,1
# 8667430,John Kens,1
# 8671889,Jake,1
# 8682794,Pearly Spencer,1
# 8690410,ibrahim Akar,1
# 8697791,bboucher,1
# 8704042,souradeep majumdar,1
# 8721010,J Selecta,1
# 8732374,Partha S. Pal,1
# 8732566,Stanislav Kundii,1
# 8735786,amba patel,1
# 8735906, wasim,1
# 8740066,SIDDHANT JAIN,1
# 8743099,MikeyB,1
# 8748139,Eric Burden,1
# 8748325,Puches,1
# 8782333,Gowtham Alan,1
# 8787194,Dominik Franek,1
# 8790816,forrestaustin,1
# 8791568,Mate Mrše,1
# 8794890,Sebastian Skurn&#243;g,1
# 8801075,Fabio,1
# 8835675,Webfreak,1
# 8837191,Divya,1
# 8838581,LukasNeugebauer,1
# 8839148,capo,1
# 8843528,SuuSoJeat,1
# 8849858,sergkondr,1
# 8859056,denmaus,1
# 8863232,kirchner,1
# 8876652,Jozef,1
# 8908237,Jack Meagher,1
# 8918721,Stephan T.,1
# 8920328,Melron,1
# 8920453,Sanche,1
# 8921755,Ivan,1
# 8935088,Ahmet Amasyalı,1
# 8938083,Jay A. Little,1
# 8940519,Renan Soares,1
# 8945164,Mario Rozic,1
# 8949644,Sagar Balyan,1
# 8956739,Daniel Gimenez,1
# 8958387,Matt,1
# 8960612,ccordon,1
# 8969139,Sandeep PC,1
# 8970591,Vasco,1
# 8972966,John_ny,1
# 8977244,Mino De Raj,1
# 8979207,nataliec,1
# 8996373,Piotr Prus,1
# 9011164,KunLun,1
# 9012170,michael_heath,1
# 9016353,kAliert,1
# 9027437,Tiago,1
# 9042681,Alexander Todorovic,1
# 9050672,Mureke,1
# 9053588,KRKirov,1
# 9058308,rohit_sethi,1
# 9062446,Juli&#225;n,1
# 9071231,Aranya,1
# 9071915,Ben,1
# 9077166,Adiosz,1
# 9083599,lGSMl,1
# 9087866,Chan,1
# 9103038,Amch,1
# 9108548,Alxmrphi,1
# 9125821,Manu Joseph,1
# 9130048,cyrus,1
# 9134576,Zlytherin,1
# 9136962,Suresh Mopidevi,1
# 9140230,Minh Nguyen,1
# 9140740,לבני מלכה,1
# 9147444,Mauricio Cele Lopez Belon,1
# 9155483,rchurch4,1
# 9156799,Luke Brady,1
# 9164471,Rene,1
# 9165946,j71261,1
# 9167318,Tanmay Gawankar,1
# 9170274,macropod,1
# 9170553,Vass,1
# 9181430,Rohit Kumar,1
# 9187215,Paresh. P,1
# 9188790,Angelina,1
# 9191057,Jerry Liu,1
# 9193147,John F,1
# 9199828,Foxfire And Burns And Burns,1
# 9203172,Pieter van der Meer,1
# 9206171,Tate Garringer,1
# 9214517,Adrian Tam,1
# 9217760,Sally CJ,1
# 9218757,Dang Nguyen,1
# 9226213,G. Tranter,1
# 9226753,Serkan T.,1
# 9232582,user9232582,1
# 9235936,Waheed Abbas,1
# 9236736,Germ&#225;n A.,1
# 9239778,Mace,1
# 9241121,yawar,1
# 9247465,Shivendra Gupta,1
# 9262523,Timur Nugmanov,1
# 9263469,Darckan,1
# 9269538,abhishek gangwar,1
# 9270577,rook99,1
# 9274323,Baraliuh,1
# 9283073,Rinki Nag,1
# 9300627,haukex,1
# 9303950,ashish pal,1
# 9305895,Kajbo,1
# 9306078,ecp,1
# 9325995,Artem Timchenko,1
# 9329398,thebrownkid,1
# 9333353,PersianIronwood,1
# 9342577,Link0,1
# 9343113,tanmoy sarker,1
# 9346859,Bilal Şimşek,1
# 9352168,elPrime,1
# 9352767,theSpacebaker,1
# 9363467,Feroz Hussain,1
# 9365913,Egor Ermolaev,1
# 9383388,CodeChuck,1
# 9391675,Saz Mifsud,1
# 9406040,Roman,1
# 9422800,Ilya Matveev,1
# 9426033,F.Ojeda,1
# 9427395,Dasun Senadeera,1
# 9435624,Marchingband,1
# 9444169,Vinod,1
# 9450912,EddieG,1
# 9451173,Jakob Kreinecker,1
# 9459662,Irineu Claro Sturza,1
# 9464882,Sektor,1
# 9466369,Hanif Budiarti,1
# 9466673,Laarni Cortez,1
# 9483405,Yanis-git,1
# 9483808,Anders Jalming,1
# 9485409,Nicole Erasga,1
# 9500333,David Daverio,1
# 9504571,Michal Gluchowski,1
# 9507545,Northern Shadow,1
# 9509383,Mike Koene,1
# 9511947,Burak Kahraman,1
# 9531261,MBB70,1
# 9533377,Dheeraj,1
# 9585016,Language Lawyer,1
# 9601964,Ajit Maurya,1
# 9609447,harvpan,1
# 9610497,Ankit Singh,1
# 9618363,guang y,1
# 9625428,Binh,1
# 9638051,Immorality,1
# 9660773,Jakebd,1
# 9663207,g_t_m,1
# 9663668,Praveen,1
# 9663800,SamirTendulkar,1
# 9665021,Haldo,1
# 9667956,Konstantin Dorogan,1
# 9688506,Law,1
# 9696928,Mobrine Hayde,1
# 9697095,Cristian Gonz&#225;lez,1
# 9705485,Ryan Dawson,1
# 9706245,RyszardTrojnacki,1
# 9710121,Nivel,1
# 9720761,Haziq Showkat Ali,1
# 9728945,anil soni,1
# 9731566,DEEPAK KUMAR,1
# 9740345,luddep,1
# 9741081,Jay Doobie,1
# 9741672,BlockchainProgrammer,1
# 9741888,Temu,1
# 9772793,DanB,1
# 9774974,Taavi Tilgre,1
# 9781122,Zeryth,1
# 9783044,Abitatha Roy,1
# 9790893,Christian Frick,1
# 9798568,Nenad Radak,1
# 9806738,Wpicode,1
# 9826929,Karol Katanowski,1
# 9829403,Tim Randall,1
# 9832922,Anji Mendpara,1
# 9839077,Mohd Umar Mubeen,1
# 9839191,Oram,1
# 9839283,Ranjeet Tiwari,1
# 9851598,surendrapanday,1
# 9851762,ItFreak,1
# 9865110,R. Conijn,1
# 9870346,Bilal Ali Jafri,1
# 9876980,Pabilo8,1
# 9883178,adrianex03,1
# 9884190,Manuel Abascal,1
# 9910265,Mohamed Ben Romdhane,1
# 9920079,Hackinet,1
# 9921853,Sergey Nudnov,1
# 9924814,plat123456789,1
# 9939875,Wenger,1
# 9950894,shrikrishna utpat,1
# 9954152,Abodesegun Ezekiel,1
# 9954578,Leonardo Freitas,1
# 9959152,Deadpool,1
# 9960138,SunnySun,1
# 9963032,yannick,1
# 9963953,user915992,1
# 9968779,Nick,1
# 9979532,Siva,1
# 9979816,Snuf,1
# 9990662,Zack,1
# 9990684,Fran,1
# 9995695,Michael Mckeough,1
# 10002608,Stigma,1
# 10007388,Matthew Delaney,1
# 10014806,Jared Anderson,1
# 10022377,Keheck,1
# 10023960,avenger012,1
# 10029810,nodediggity,1
# 10035556,Mayur,1
# 10046127,milkice,1
# 10067019,ajbieber,1
# 10067621,TheLuckyRobot,1
# 10089328,Lucas Hort,1
# 10093353,Jonny van Beek,1
# 10095046,Kemal Atik,1
# 10099383,kivul,1
# 10109503,lazyezy,1
# 10114843,Julian,1
# 10114881,Ameya Shinde,1
# 10115111,Henrik Stanley Mortensen,1
# 10119916,Hiroyuki Abe,1
# 10127883,M MERE,1
# 10130385,Rohit Saigal,1
# 10136560,aaron lilly,1
# 10148053,Daniel B.,1
# 10150532,devendra,1
# 10152403,Golam Sorwar,1
# 10155816,David Sommer,1
# 10160878,Deepak Kumar,1
# 10161287,Daniel Martinez Condinanza,1
# 10165762,dirk,1
# 10170533,Tolga Karahan,1
# 10172408,Nathan Wright,1
# 10192842,Klonept,1
# 10195153,danblack,1
# 10201613,tom S,1
# 10228119,Amas,1
# 10231078,Ehsan Habib,1
# 10240836,roy,1
# 10245397,Gil M,1
# 10248678,oguzismail,1
# 10251701,Dariusz Basznianin,1
# 10256832,Antoine Carpentier,1
# 10257091,cssenior,1
# 10263645,NF38,1
# 10266675,Johan Rosa,1
# 10269666,Zeta,1
# 10271067,Luis Bonilla,1
# 10273013,Mayur Vaghasiya,1
# 10273504,JoePythonKing,1
# 10277306,l h,1
# 10289144,Adam W.,1
# 10294519,timmy,1
# 10304059,jsRook,1
# 10309381,Deepak-MSFT,1
# 10311733,Piotr Wicijowski,1
# 10314162,George Hanson,1
# 10315921,tableware,1
# 10316640,Strom,1
# 10323648,T T,1
# 10329562,graywolf,1
# 10334856,User,1
# 10335956,E.Coms,1
# 10343822,TheBeardedDev,1
# 10347794,Nepomucen,1
# 10351719,Lester Solbakken,1
# 10356699,JoseMiguez98,1
# 10357316,Martin,1
# 10364045,sit_on_a_pan_otis,1
# 10372855,David Ogutu,1
# 10375820,shubham singh,1
# 10378715,shane,1
# 10380101,AbuBakar Khan,1
# 10385447,white hills,1
# 10387670,mifydnu,1
# 10388146,kamyar haqqani,1
# 10393276,gpskipton,1
# 10409564,Siva Gudivada,1
# 10412921,Nagaraju Chimmani,1
# 10426557,Jonathan Johx,1
# 10429036,Oliver Nybo,1
# 10429618,Tom Zwakhals,1
# 10430329,Artyom Amiryan,1
# 10436909,Antonio Faria,1
# 10438295,blaad,1
# 10441424,Eric Ransom,1
# 10449481,maggie wan,1
# 10474129,MDrX,1
# 10480821,vrtex,1
# 10484567,Gnbrkm41,1
# 10487763,Jenifer Jiang,1
# 10490295,MrAndersonk,1
# 10493338,JustAProgrammer,1
# 10498410,angie,1
# 10498584,Pabloks,1
# 10499751,Lukas Neumann,1
# 10505793,R.Sarkar,1
# 10514104,Casey Anderson,1
# 10519617,Stefmachine,1
# 10520928,Victor Fortman,1
# 10522176,Lars,1
# 10522567,dash2,1
# 10525061,Yantup,1
# 10527277,m mukai,1
# 10553098,John,1
# 10554218,PHPNoob,1
# 10558088,ZDL-so,1
# 10576317,Goncalo,1
# 10578782,shivkanya kaile,1
# 10582347,Timo Frionnet,1
# 10583418,JT Dong,1
# 10586395,Cem,1
# 10587187,mava,1
# 10589083,Prashanthkumar R,1
# 10590138,adam90,1
# 10600584,lau,1
# 10601349,Alexander Gonzalez,1
# 10604378,Muljayan,1
# 10604910,giladk,1
# 10606400,Swati,1
# 10612111,MullisS,1
# 10612606,heilerich,1
# 10613463,dganenco,1
# 10614091,level3looper,1
# 10618375,Lucas Piazzi,1
# 10621834,Shuvodeep Biswas,1
# 10622277,G. Egli,1
# 10622916,Bodo,1
# 10624646,Data Science,1
# 10628493,Vladimir Zakharevych,1
# 10629305,William,1
# 10630172,Greg Moens,1
# 10651098,user10651098,1
# 10653328,angoyal-msft,1
# 10654347,Bodrov,1
# 10664194,Matt C,1
# 10677049,M.Hem,1
# 10682289,JaSON,1
# 10691050,Togi,1
# 10691496,Section,1
# 10691911,ThisIsMe,1
# 10699085,Mert Beşiktepe,1
# 10699171,J.D.,1
# 10705006,Valentin,1
# 10705362,mukhtar alam,1
# 10706550,Thao Ly,1
# 10710731,Hemil,1
# 10716514,Loghin Alexandru,1
# 10718110,SamW,1
# 10719619,Oly,1
# 10722923,Lukasz Tomasik,1
# 10738034,Sewagodimo Matlapeng,1
# 10748500,user10748500,1
# 10757985,Nikitha Nadig,1
# 10761889,Matt,1
# 10768496,bkk,1
# 10772274,Mamun,1
# 10773803,Curious,1
# 10773965,Ratchet,1
# 10776519,Mike ,1
# 10781632,Shailendra Dobhal,1
# 10786177,Eduardo Reyna  Credencie Consu,1
# 10786914,dtanabe,1
# 10787900,Bibberty,1
# 10788025,James Kelley,1
# 10788397,dom,1
# 10789312,liaquore,1
# 10791205,Namo,1
# 10799631,Tammana Nankani,1
# 10801162,klassnyy,1
# 10806801,Reece Taylor,1
# 10807847,&#192;tishking,1
# 10809490,Tugrul Yildirim,1
# 10810093,Faris Tangastani,1
# 10812286,muhammad amer,1
# 10815144,Miguel Santos,1
# 10815608,Anoos,1
# 10815653,ExploreR,1
# 10817919,Mateusz Krzyżanowski,1
# 10823490,Jackal,1
# 10827064,oemel09,1
# 10840270,Virgil Ionescu,1
# 10847825,Ayman,1
# 10853379,YuanDa.Yu,1
# 10853463,red_menace,1
# 10855855,Felipass,1
# 10856926,Dev KACST,1
# 10859424,Jos&#233; Ra&#250;l Toledano R,1
# 10860086,mdrichardson,1
# 10862097,Anudeep Reddy,1
# 10862144,RC0993,1
# 10867430,mfrackowiak,1
# 10868492,JediMan4ik,1
# 10868666,Adam Waldenberg,1
# 10869431,Ayuthia,1
# 10877760,RainerS,1
# 10882696,cognitive,1
# 10882927,Maksim Koniukhov,1
# 10883652,E.Benedos,1
# 10886515,sbehnken,1
# 10891487,Student,1
# 10892554,Empty,1
# 10896197,ozrlz,1
# 10896702,Artur Vakhrameev,1
# 10897855,NPCampbell,1
# 10898604,underthecode,1
# 10902077,jmgarrido,1
# 10903573,passion,1
# 10906068,Nancy Mooree,1
# 10907320,SCYang,1
# 10909012,Julian Valentine,1
# 10909167,Yusei Saito,1
# 10914289,tdev,1
# 10915211,Pipiasi Bogdan,1
# 10917113,Gus,1
# 10917129,Erland Huam&#225;n,1
# 10921728,Sonata,1
# 10923157,Bill Miller,1
# 10925378,Jay,1
# 10927251,Benjamin MASSET,1
# 10927869,Dig&#227;o Dalpiaz,1
# 10932128,Delaporte,1
# 10933884,John Martin,1
# 10934392,Esteban Bonilla Velasquez,1
# 10935761,GameChanger,1
# 10937190,Prasoon,1
# 10939536,Abdulrahman Althawadi ,1
# 10939976,Suyash Chavan,1
# 10941101,mohi1618,1
# 10941657,Colorscream,1
# 10943775,Malcolmn Roberts,1
# 10943932,szymonszymon,1
# 10943992,user10943992,1
# 10945362,Muthuraj M,1
# 10946129,tejdeep ijjapureddi,1
# 10946220,user_es25,1
# 10946420,Amelia_s,1
# 10946464,Phoxeh,1
# 10946750,Shubham Bhardwaj,1
# 10946793,Ender,1
# 10947143,milk taco,1
# 10947613,CoreZz,1
# 10948502,spoikayi,1
# 10949543,Robb216,1
# 10950107,Pavan Vanam,1
# 10950352,chitresh,1
# 10950471,Igor Fagundes,1
# 10950834,Andy,1
# 10951306,Rez,1
# 10951874,Florian,1
# 10952215,Bob Shaffer,1
# 10953085,RosA,1
# 10953097,Asmaa Alshaer,1
# 10953735,youngcheol kang,1
# 10953948,vonRo,1
# 10953984,Niek Waarbroek,1
# 10953999,user10953999,1
# 10954304,Marion ,1
# 10954730,灵翼俠,1
# 10954987,TienNguyen,1
# 10955657,Baddl,1
# 10956098,Didier,1
# 10956463,Lojtra,1
# 10956497,Veit Stooss,1
# 10956532,don.johnsy,1
# 10957072,Medium core,1
# 10957124,Clint,1
# 10957186,JOAO LUCAS,1
# 10957374,jean qwijul,1
# 10957388,Vasudeva Reddy,1
# 10957411,Kurt Enget,1
# 10957484,Farzaneh gholamnejad,1
# 10957648,Brian W Chen,1
# 10957685,Dmitry,1
# 10957820,Kosar,1
# 10957866,K Kumar,1
# 10958072,user10958072,1
# 10958149,mehmet veysel Yağcı,1
# 10958183,jagodfrey,1
# 10958194,user10958194,1
# 10958218,Alexander Militenko,1
# 10958256,Paul Pirie,1
# 10958283,Denis.h,1
# 10958324,SchmadenWTGGTTTGG,1
# 10958465,Matthew T,1
# 10958468,Snbig,1
# 10958483,Joe,1
# 10958586,Passer Thru,1
# 10958588,YouseeF.,1
# 10958612,Phillip Wessels,1
# 10958798,Zurc Soirrab,1
# 10958825,Oreo Cat,1
# 10958842,guest,1
# 10958847,Jikle,1
# 10959091,xiaoc024,1
# 10959173,user10959173,1
# 10959229,haruraruru,1
# 10959250,Mukesh Kumar yadav,1
# 10959420,Ruta Utture,1
# 10959478,Donkkas,1
# 10959533,Fil Nomatter,1
# 10959564,shan,1
# 10959600,Arjun Shukla,1
# 10959653,Adnan,1
# 10959698,user10959698,1
# 10959732,aravin,1
# 10959820,yamini merchant,1
# 10959911,Jignesh Dadhaniya,1
# 10959922,user10959922,1
# 10960077,Dale,1
# 10960086,Jacopp,1
# 10960087,Pavan Raju,1
# 10960093,Yann Mingant,1
# 10960332,Annick Van Bergen,1
# 10960346,Mayank Pareek,1
# 10960375,J. Doe,1
# 10960430,Michael Weber,1
# 10960535,Esra &#199;İ&#199;EKBAL,1
# 10960592, Senpaivg,1
# 10960608,dev_jazz,1
# 10960650,F. Pelucchi,1
# 10960687,Shang Wu,1
# 10960743,Nguyễn Mạnh Cường,1
# 10960748,user10960748,1
# 10960801,SWQA,1
# 10960819,Hamid Raza,1
# 10960826,user10960826,1
# 10960852,perun10,1
# 10961008,Ras C-kay sKatle,1
# 10961136,subin_v_s,1
# 10961145,Cmdr.Hawkeye,1
# 10961155,Botond Balint,1
# 10961253,Kit,1
# 10961328,Chao Chen,1
# 10961331,Fazlur,1
# 10961341,John Doe,1
# 10961342,Thymen,1
# 10961448,Deependra Kumar,1
# 10961521,Louis Pie,1
# 10961656,Prashant Dahat,1
# 10961684,prem,1
# 10961722,softwareengineeradvisor,1
# 10961746,Jo&#227;o Batista,1
# 10961768,Daniel Valchev,1
# 10961850,BR WORKS,1
# 10961870,Kush,1
# 10961899,Dazzler,1
# 10961950,Oscar Ca&#241;&#243;n,1
# 10962078,Mathias Winterhalter,1
# 10962119,Thomaz R. Damasceno,1
# 10962289,David,1
# 10962316,Mayur Bhardwaj,1
# 10962364,Mohit Maroliya B17CS036,1
# 10962374,Bob Roche,1
# 10962477,Suhas_Pote,1
# 10962541,Louis Stephens,1
# 10962571,Д Ж,1
# 10962594,Chen Z,1
# 10962659,user10962659,1
# 10962869,Michael Leeming,1
# 10962916,Jessica Potter - CDA,1
# 10963003,Itamar Gam,1
# 10963046,a_bodkin_betwixt_the_knaves,1
# 10963137,dinesh,1
# 10963148,jose,1
# 10963151,user10963151,1
# 10963156,Idan Shalom Agamy,1
# 10963227,Sanjeev Kumar,1
# 10963238,packet_brain,1
# 10963253,Tom Smith,1
# 10963347,홍기범,1
# 8651667,Juha Vehnia,1

# %% [markdown]
# Ahora consultamos las localizaciones mas activas

# %%
# !gsutil cp -r gs://$BUCKET_NAME/locations_most_actives .
# !cat locations_most_actives/*
# Out:
# Copying gs://dataproc-d3c1f40b-c187-47f1-a030-87fd5670b613-europe-north1/locations_most_actives/000000_0...
# / [1 files][ 11.5 KiB/ 11.5 KiB]
# Operation completed over 1 objects/11.5 KiB.
# None,2851
# London,395
# New York,289
# Nicosia,276
# D&#252;sseldorf,230
# Bangalore,158
# Hyderabad,143
# Pune,115
# United States,106
# Ahmedabad,94
# Germany,93
# Sydney,92
# Dhaka,91
# India,89
# San Francisco,87
# Houston,84
# Melbourne VIC,8
# Ypres,8
# Richmond,8
# Sarasota,8
# Godoy Cruz,8
# San Lazzaro di Savena,8
# Brazil,8
# Kolkata,8
# Quebec,8
# Helsinki,8
# Old Saybrook,8
# Flyover Country,8
# Ulm,8
# M&#252;nchen,8
# Sofia,8
# Bagneux,8
# Maryland,8
# Belarus,7
# Copenhagen,7
# Egypt,7
# Croatia,7
# Gliwice,7
# Brisbane,7
# Waterloo,7
# Malaysia,7
# Wrocław,7
# San Jose,7
# Europe,7
# Samara,7
# China,7
# Manila,7
# Sri Lanka,7
# Silicon Valley,7
# Sacramento,7
# Ireland,7
# Lagos,7
# Indore,7
# Lille,7
# Stoke-on-Trent,7
# Kuril,6
# Carlisle,6
# Aachen,6
# Berkeley,6
# San Diego,6
# Vila Do Corvo,6
# Heidelberg,6
# Blieskastel,6
# St. Petersburg,6
# Ohio,6
# Bogot&#225;,6
# Coimbatore,6
# Utrecht,6
# Bologna,6
# Brooklyn,6
# Barisal,6
# United Arab Emirates,6
# Ambridge,6
# Timișoara,6
# Wichita,6
# West Midlands,6
# Rainbow,6
# Osnabr&#252;ck,6
# milky way galaxy,6
# Russia,6
# Košice,6
# Mosc&#250;,6
# Rockville,6
# Glasgow,6
# Rochester,6
# Rome,6
# Mountain View,6
# Wayne,6
# Iran,6
# Cisco,6
# Ciudad Obreg&#243;n,6
# Czech Republic,6
# El Salvador,6
# Canterbury,6
# PL,6
# Phagwara,6
# Victoria,6
# Augsburg,6
# Fully,6
# india,5
# Algiers,5
# Chandigarh,5
# Charlotte,5
# Madrid,5
# Bulgaria,5
# Seoul,5
# Tehran,5
# Ankara,5
# Costa Rica,5
# Brescia,5
# Deutschland,5
# S&#227;o Paulo,5
# Manchester,5
# Toulouse,5
# Portugal,5
# Valencia,5
# Kharkov,5
# Massachusetts,5
# Louisiana,5
# Japan,5
# Belgi&#235;,5
# Nepal,5
# Nairobi,5
# Valle de Bravo,4
# Peterborough,4
# Washington D.C.,4
# Gandhinagar,4
# Turkey,4
# Gloucestershire,4
# Constanța,4
# Manosque,4
# Porto,4
# Ghaziabad,4
# Finland,4
# Connecticut,4
# Karaj,4
# Hungary,4
# Rio de Janeiro,4
# Bangkok Yai Bangkok Thailand,4
# Earth planet,4
# &#206;le-de-France,4
# Kiev City,4
# Krakow,4
# The Woodlands,4
# Durham,4
# Berkshire,4
# S-Petersburg,4
# Orlando,4
# Zhytomyr,4
# Michigan,4
# Vadodara,4
# Shanghai,4
# Brasil,4
# Katowice,4
# Cape Town,4
# Williamsburg,4
# Bavaria,4
# Ipswich,4
# M&#252;nster,4
# Florida,4
# Ho Chi Minh City,4
# Krasnoyarsk,4
# Slagharen,4
# Modena,4
# Poznań,4
# Salo,4
# Lehi,4
# Jacksonville,3
# Southampton,3
# Turin,3
# irrelevant,3
# Quinson,3
# Gothenburg,3
# Arizona,3
# UTC -6:00/-5:00 CST/CDT https://www.timeanddate.com/time/zones/cdt,3
# Palestine,3
# Grenoble,3
# Essen,3
# outside Washington DC,1
# Bhiwandi,1
# Bhilai,1
# Berne,1
# Bergen County,1
# US west coast,1
# Bergen,1
# Beograd,1
# Udaipur,1
# Bentonville,1
# Belvedere CA,1
# Ulverston,1
# Unitd Stuts of Murka,1
# Belo Horizonte - MG,1
# Bellingham,1
# Belgrade,1
# programming Universe,1
# Belgique,1
# Usak,1
# Beirut,1
# Beijing China,1
# Uttara,1
# V&#228;stervik,1
# Bay Area,1
# Batala,1
# Bartın,1
# Banska Bystrica,1
# Varna,1
# san jose,1
# Bangkok Thailand,1
# Bandar Abbas,1
# Venus,1
# secret,1
# Baltimore,1
# Bahrain,1
# Vienna/Austria,1
# Bagh-i-Mehtab,1
# Vilnius,1
# Ljubljana,1
# Lodi,1
# Vimodrone,1
# Little Rock,1
# London Ontario,1
# Baeza,1
# Little Falls,1
# Long Island City,1
# Longueuil,1
# Leipzig,1
# Leeds,1
# Lansing,1
# Virginia Beach,1
# Lugano,1
# Lakeville,1
# trivandrum,1
# Volodymyrets&#39;,1
# Lyon,1
# Lyon - France,1
# M&#225;laga,1
# La Canourgue,1
# Kuliyapitiya,1
# Kuala Lumpur Malaysia,1
# MCR,1
# Kuala Lumpur Federal Territory of Kuala Lumpur Malaysia,1
# Macon,1
# Kreuzau,1
# Madurai,1
# Maharagama,1
# Kozhikode,1
# Voronezh,1
# Malaga,1
# Kortrijk,1
# Kirkland,1
# Malmo,1
# Malta,1
# Kingdom of Rust,1
# Killarney,1
# Mannheim,1
# Bad Camberg,1
# Kielce,1
# Mars,1
# Ayacucho,1
# Khmelnitskaya oblast&#39;,1
# Kermanshah,1
# Kazan&#39;,1
# Katy,1
# Avellino,1
# Medford,1
# Kathmandu,1
# Karlskrona,1
# Memphis,1
# Merseyside,1
# Austrlia,1
# Kanpur,1
# Australian Capital Territory,1
# Kampong Cham,1
# Midland,1
# Milan,1
# Milano,1
# Miles from anywhere,1
# Milky Way Galaxy,1
# Milton Keynes,1
# Auburn,1
# Minnesota,1
# Kakamega,1
# Washington DC,1
# Mishawaka,1
# Kailua Kona,1
# Moga,1
# Moldova,1
# Mongolia,1
# Monselice,1
# Montenegro,1

# %%
# Por ultimo, al no tener que usar mas el cluster, lo eliminamos
def delete_cluster(dataproc, project, region, cluster):
  print('Tearing down cluster')
  result = dataproc.projects().regions().clusters().delete(
    projectId=project,
    region=region,
    clusterName=cluster).execute()
  return result

delete_cluster(dataproc, project_id, region, cluster_name)
# Out:
# Tearing down cluster
# {'metadata': {'@type': 'type.googleapis.com/google.cloud.dataproc.v1.ClusterOperationMetadata',
#   'clusterName': 'cluster-bdarchitecture-stackoverflow',
#   'clusterUuid': '364ad0fc-807e-4906-be34-c4accb397daa',
#   'description': 'Delete cluster',
#   'operationType': 'DELETE',
#   'status': {'innerState': 'PENDING',
#    'state': 'PENDING',
#    'stateStartTime': '2019-01-24T18:19:46.933Z'}},
#  'name': 'projects/positive-record-228820/regions/europe-west4/operations/c11f3534-17e7-412a-b4cc-fb8371622aba'}
